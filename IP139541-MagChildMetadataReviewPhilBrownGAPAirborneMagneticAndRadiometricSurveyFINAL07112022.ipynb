# %% [markdown]
# <img align="left" width="105" height="105" src="https://www.doi.gov/sites/doi.opengov.ibmcloud.com/themes/custom/doi_gov/logo.png">
#
#
# <center><b>&nbsp;&nbsp;&nbsp;United States Department of the Interior</b></center>
#
# <center><b>&nbsp;&nbsp;&nbsp;U.S. GEOLOGICAL SURVEY</b></center>
#
# <center><b>Geology, Geophysics, and Geochemistry Science Center</b></center>
# <br>
# July 07, 2022
#
# <h1>Airborne horizontal magnetic gradient and radiometric survey over parts of southeast Missouri, southern Illinois and western Kentucky- The Gap survey, 2021 metadata and data review</h1>
#
# To:	Dylan Connell, Geophysicist Denver, Geology, Geophysics, and Geochemistry Science Center
#
# From: Philip J. Brown, Geophysicist, Denver, Geology, Geophysics, and Geochemistry Science Center
#
# Subject:
# <br>
# Metadata Review of, Airborne horizontal magnetic gradient and radiometric survey over parts of southeast Missouri, southern Illinois and western Kentucky- The Gap survey, 2021 <br>
#
# IP-134240
#
# McCafferty, A.E. and Connell, D.M., 2022, Airborne horizontal-magnetic gradient and radiometric survey over parts of southeast Missouri, southern Illinois and western Kentucky- The Gap survey, 2021: U.S. Geological Survey data release, https://doi.org/10.5066/P9TK8KMM.
#
# https://www.sciencebase.gov/catalog/item/624347bfd34e22d73748d357
#
# This metadata was reviewed using the USGS checklists found on the G3 ScienceCenter DataManagment Intranet Sharepoint Site, https://doimspp.sharepoint.com/sites/GS-GGGSC/DM.
#
# Information on the status of this data release can be found at the DMTeam Data Release Tracking SharePoint Site, https://doimspp.sharepoint.com/sites/GGGSCDataManagementTeam/Lists/Data%20Release%20Tracking/Status%20View.aspx

# %%
# Load required Libraries
import sys
import os
import xml.etree.ElementTree as ET
import pandas as pd
import numpy as np
from IPython.core.display import display
from IPython.core.display import HTML
from ipywidgets import *
from IPython.display import display
from IPython.html.widgets import widgets
import datetime
import dateutil.parser
import time
import ssl
import json
import sys
import sciencebasepy as pysb
#Create Function that allows one to implement markdown display when printing
from IPython.display import Markdown, display
def printmd(string):
    display(Markdown(string))
# Out:
# C:\Users\pbrown\Anaconda3\lib\site-packages\IPython\html.py:12: ShimWarning: The `IPython.html` package has been deprecated since IPython 4.0. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   warn("The `IPython.html` package has been deprecated since IPython 4.0. "

# %% [markdown]
# ## **Parent Metadata Review -** ***MO20F0196_GAP_FGDCmetadata.xml***
# ### 1)	Validate metadata with validation tool (https://mrdata.usgs.gov/validation/) and note compliance issues:

# %%
#Set paths metadata
ChildPath = r"C:\CurrentWork\DataReleaseReviews\IP-139541Gap\MagChild"
ChildMetadata = 'MO20F0196_GAP_MagChild_FGDCmetadataFINAL.xml'

# %% [markdown]
# <h3>Validation and re-expression of SC19C0010_SCII_FallZone_MagChild_FGDCmetadata.xml</h3>
# <pre>
# mp 2.9.52 - Peter N. Schweitzer (U.S. Geological Survey)
# Info: input file = php4itxJE.xml
# Info: process date = 20220707
# Info: process time = 13:25:41
# No errors
# <h3 style="color: #006633;">Secondary validation results</h3>
# <table class="table table-condensed table-bordered">
#   <thead>
#     <tr>
#       <th scope="col">Test</th>
#       <th scope="col">Result</th>
#       <th scope="col">Report</th>
#     </tr>
#   </thead>
#   <tbody style="font-size: small;">
#     <tr>
#       <td>Online_Linkage</td>
#       <td style="background-color: #ff9999;">Failure</td>
#       <td style="white-space: pre;">Invalid Online_Linkage in Citation: &quot;https://doi.org/10.5066/P9TK8KMM&quot;
# Valid link in Citation: &quot;https://pubs.usgs.gov/fs/2019/3007/fs20193007.pdf&quot;
# Invalid Network_Resource_Name: &quot;https://www.sciencebase.gov/catalog/file/get/62434c50d34e22d73748d366?f=__disk__68%2F98%2Fdb%2F6898db1da809a774f7ed36d4d7a82a6afd517465&quot;
# Invalid Network_Resource_Name: &quot;https://doi.org/10.5066/P9TK8KMM&quot;
# Invalid Network_Resource_Name: &quot;https://www.sciencebase.gov/catalog/item/62434c50d34e22d73748d366&quot;
# Invalid Network_Resource_Name: &quot;https://www.sciencebase.gov/catalog/file/get/62434c50d34e22d73748d366?f=__disk__20%2Fc9%2F37%2F20c93713022bcbe655c26bbac2ccca0dd3f3221a&quot;
# Invalid Network_Resource_Name: &quot;https://www.sciencebase.gov/catalog/file/get/62434c50d34e22d73748d366?f=__disk__ab%2F63%2Fd3%2Fab63d3d78ee5dc5c9dc7552d6d4fdbbaca9fb9a2&quot;
# Invalid Network_Resource_Name: &quot;https://www.sciencebase.gov/catalog/file/get/62434c50d34e22d73748d366?f=__disk__20%2Fc9%2F37%2F20c93713022bcbe655c26bbac2ccca0dd3f3221a&quot;
# </td>
#     </tr>
#     <tr>
#       <td>ISO 19115 Topic Category</td>
#       <td style="background-color: #99ff99;">Success</td>
#       <td style="white-space: pre;">All 2 keywords are valid</td>
#     </tr>
#     <tr>
#       <td>USGS Thesaurus</td>
#       <td style="background-color: #ff9999;">Failure</td>
#       <td style="white-space: pre;">Unrecognized keyword: &quot;economy&quot;
# Unrecognized keyword: &quot;geoscientific information&quot;
# Unrecognized keyword: &quot;horizontal magnetic gradiometry&quot;</td>
#     </tr>
#     <tr>
#       <td>Common geographic areas</td>
#       <td style="background-color: #99ff99;">Success</td>
#       <td style="white-space: pre;">All 4 keywords are valid</td>
#     </tr>
#     <tr>
#       <td>USGS publication series</td>
#       <td style="background-color: #ff9999;">Failure</td>
#       <td style="white-space: pre;">Unrecognized series name &quot;Mapping the nations critical mineral resources: U.S. Geological Survey Fact Sheet 2019-3007&quot;</td>
#     </tr>
#     <tr>
#       <td>Format_Name</td>
#       <td style="background-color: #ffff99;">Warning</td>
#       <td style="white-space: pre;">Non-preferred format name: &quot;CSV&quot;
# Non-preferred format name: &quot;JPG&quot;</td>
#     </tr>
#     <tr>
#       <td>Suggest terms</td>
#       <td style="background-color: #ffff99;">Warning</td>
#       <td style="white-space: pre;">No matching terms were found</td>
#     </tr>
#     <tr>
#       <td>Standard name, version</td>
#       <td style="background-color: #99ff99;">Success</td>
#       <td style="white-space: pre;">Metadata_Standard_Name is valid</td>
#     </tr>
#   </tbody>
# </table>

# %%
#open and parse metadata
ChildMetadataPath = ChildPath + "\\" + ChildMetadata
ParentTree = ET.parse(ChildMetadataPath)
root = ParentTree.getroot()

# %% [markdown]
# ### 2)	 The title conveys the “what, where, when, who, and (if applicable) scale” of the data;

# %%
#Get title from metadata
for citeinfo in root.iter('citeinfo'):
 title = citeinfo.find('title')
 printmd ('**' + title.text + '**')
# Out:
# **Airborne magnetic flight line data over parts of southeast Missouri, southern Illinois and western Kentucky- The Gap survey, 2021**
# **The Earth MappingResources Initiative (Earth MRI)**

# %% [markdown]
# > - No recommended changes to title

# %% [markdown]
# ### 3)	The abstract provides a short statement that allows users to quickly evaluate the content of the dataset:

# %%
#Get abstract from metadata
for descript in root.iter('descript'):
 abstract = descript.find('abstract')
 purpose = descript.find('purpose')
 print (abstract.text)
# Out:
# Airborne magnetic gradiometry data along the tie and flight lines are provided here in CSV (Comma Separated Value) format along with a GeoTIFF grid of the total magnetic intensity (TMI) in nanoTeslas.  Along with the data provided on this child page, a report in PDF format by the airborne contractor that describes the technical details of the data collection, reduction and processing procedures and a zip file that contains the contractor's deliverable products (Geosoft databases and grids) for the magnetic and radiometric survey is available on the parent page (https://doi.org/10.5066/P9TK8KMM).

# %% [markdown]
# > - No recommended changes to the abstract.

# %%
# Get Purpose from metadata
print (purpose.text)
# Out:
# The airborne magnetic and radiometric survey was designed to augment and connect several previous USGS geophysical surveys in order to provide a continuous representation of the magnetic and radiometric fields from southeast Missouri to western Kentucky. These data will be used to better understand the surface and concealed geologic framework.

# %% [markdown]
# - No recommended changes to purpose

# %% [markdown]
# ### 4)	Perform quality checks on metadata:
# ##### a.	The metadata matches the data and its correct version (e.g., is this metadata record describing the correct dataset? Sometimes existing metadata records are used as templates and some old information carries over to the new record:

# %%
# Get metadata and print it out
metaData = ET.tostring(root, encoding='utf8').decode('utf8')
print(metaData)
# Out:
# <?xml version='1.0' encoding='utf8'?>
# <metadata>
# 	<idinfo>
# 		<citation>
# 			<citeinfo>
# 				<origin>Anne E. McCafferty</origin>
# 				<origin>Dylan M Connell</origin>
# 				<pubdate>20220404</pubdate>
# 				<title>Airborne magnetic flight line data over parts of southeast Missouri, southern Illinois and western Kentucky- The Gap survey, 2021</title>
# 				<geoform>tabular digital data</geoform>
# 				<pubinfo>
# 					<pubplace>Denver, CO</pubplace>
# 					<publish>U.S. Geological Survey</publish>
# 				</pubinfo>
# 				<othercit>Additional information about Originators: Ann E. McCafferty, https://orcid.org/0000-0001-5574-9201; Dylan M. Connell, https://orcid.org/0000-0001-8678-2776.  Suggested Citation: McCafferty, A.E. and Connell, D.M., 2022, Airborne horizontal-magnetic gradient and radiometric survey over parts of southeast Missouri, southern Illinois and western Kentucky- The Gap survey, 2021: U.S. Geological Survey data release, https://doi.org/10.5066/P9TK8KMM.</othercit>
# 				<onlink>https://doi.org/10.5066/P9TK8KMM</onlink>
# 				<lworkcit>
# 					<citeinfo>
# 						<origin>Day, W.D.</origin>
# 						<pubdate>2019</pubdate>
# 						<title>The Earth MappingResources Initiative (Earth MRI)</title>
# 						<edition>1.0</edition>
# 						<serinfo>
# 							<sername>Mapping the nations critical mineral resources: U.S. Geological Survey Fact Sheet 2019-3007</sername>
# 							<issue>2019-3007</issue>
# 						</serinfo>
# 						<pubinfo>
# 							<pubplace>Reston, VA</pubplace>
# 							<publish>United States Geological Survey</publish>
# 						</pubinfo>
# 						<othercit>Day, W.D., 2019, The Earth MappingResources Initiative (Earth MRI): Mapping the nations critical mineral resources: U.S. Geological Survey Fact Sheet 2019-3007, https://pubs.usgs.gov/fs/2019/3007/fs20193007.pdf.</othercit>
# 						<onlink>https://pubs.usgs.gov/fs/2019/3007/fs20193007.pdf</onlink>
# 						<onlink>https://permanent.fdlp.gov/gpo117974/fs20193007.pdf</onlink>
# 						<onlink>https://www.usgs.gov/special-topics/earth-mri</onlink>
# 					</citeinfo>
# 				</lworkcit>
# 			</citeinfo>
# 		</citation>
# 		<descript>
# 			<abstract>Airborne magnetic gradiometry data along the tie and flight lines are provided here in CSV (Comma Separated Value) format along with a GeoTIFF grid of the total magnetic intensity (TMI) in nanoTeslas.  Along with the data provided on this child page, a report in PDF format by the airborne contractor that describes the technical details of the data collection, reduction and processing procedures and a zip file that contains the contractor's deliverable products (Geosoft databases and grids) for the magnetic and radiometric survey is available on the parent page (https://doi.org/10.5066/P9TK8KMM).
#
# </abstract>
# 			<purpose>The airborne magnetic and radiometric survey was designed to augment and connect several previous USGS geophysical surveys in order to provide a continuous representation of the magnetic and radiometric fields from southeast Missouri to western Kentucky. These data will be used to better understand the surface and concealed geologic framework.</purpose>
# 			<supplinf>Data for this survey were collected by Terraquest, Ltd. under contract with the USGS using a fixed wing aircraft with magnetometers mounted in the tail stinger and each wing tip pod and a fully calibrated gamma ray spectrometer. The survey operated out of the Farmington, Missouri airport from March of 2021 to July of 2021. The survey covers a 88-kilometer x 160-kilometer area. Data were collected along east-west flight lines spaced 250 meters (m) apart with north-south tie lines flown every 3500 m. A mean terrain clearance of 100 m was maintained except where safety dictated a higher elevation. A total of 64,233-line kilometers (km) of data were collected.
#
# The Gap survey was designed to "fill the gap" between two high-resolution airborne magnetic and radiometric surveys collected in previous years by the USGS.  The Gap survey fills in the area between the previous surveys allowing for a continuous magnetic and radiometric coverage across a large area of the southern Midcontinent.  Data for the previous surveys are available by clicking on the "Associated Items" link on the parent page.
#
# Files that are available in this publication include flight line data for the magnetic survey in an ascii .csv file, flight line data for the radiometric survey in a netcdf file, geoTIFF images of the total magnetic intensity and radiometric ternary image of potassium, thorium, and uranium values, and a report describing the survey parameters, field operations, quality control and data reduction procedures. A zip file containing the contractor's deliverable products is also included and contains radiometric spectra in a geosoft format database (gdb).  Binary files in the original contractor package are readable using the free software "Geosoft Viewer" or commercial software "Oasis montaj."
#
# Data null value is -1e32 for tabular data and (RGB value) 255,255,255 for raster data.
#
# MO20F0196_GAP_MagChild_FGDCmetadata.xml
# TotalMagneticIntensity.jpg
# MO20F0196_GAP_DataDictionary_MAG_data.json
# MO20F0196_USGS_GAP_TMI_wgs84z16n.tif
# MO20F0196_USGS_GAP_MagneticFlightLineData.csv
#
# Other References:
# Day, W.D., 2019, The Earth Mapping Resources Initiative (Earth MRI): Mapping the nation's critical mineral resources: U.S. Geological Survey Fact Sheet 2019-3007, https://doi.org/10.3133/fs20193007.
#
# McCafferty, A.E., and Johnson, M.R., 2019, Airborne magnetic and radiometric survey, southeast Missouri and western Illinois, 2018-2019: U.S. Geological Survey data release, https://doi.org/10.5066/P9PBDSA1.
#
# McCafferty, A.E., and Brown, P.J., 2020, Airborne magnetic and radiometric survey, southeastern Illinois, western Kentucky, and southern Indiana, 2019: U.S. Geological Survey data release, https://doi.org/10.5066/P9R05B0M</supplinf>
# 		</descript>
# 		<timeperd>
# 			<timeinfo>
# 				<rngdates>
# 					<begdate>20200302</begdate>
# 					<enddate>20210420</enddate>
# 				</rngdates>
# 			</timeinfo>
# 			<current>ground condition</current>
# 		</timeperd>
# 		<status>
# 			<progress>Complete</progress>
# 			<update>None planned</update>
# 		</status>
# 		<spdom>
# 			<bounding>
# 				<westbc>-89.9509</westbc>
# 				<eastbc>-88.8396</eastbc>
# 				<northbc>38.2952</northbc>
# 				<southbc>36.8304</southbc>
# 			</bounding>
# 		</spdom>
# 		<keywords>
# 			<theme>
# 				<themekt>USGS Thesaurus</themekt>
# 				<themekey>economy</themekey>
# 				<themekey>geophysics</themekey>
# 				<themekey>geospatial datasets</themekey>
# 				<themekey>geoscientific information</themekey>
# 				<themekey>aeromagnetic surveying</themekey>
# 				<themekey>magnetic field (earth)</themekey>
# 				<themekey>horizontal magnetic gradiometry</themekey>
# 				<themekey>aeroradiometric surveying</themekey>
# 				<themekey>potassium</themekey>
# 				<themekey>uranium</themekey>
# 				<themekey>thorium</themekey>
# 				<themekey>radon</themekey>
# 			</theme>
# 			<theme>
# 				<themekt>none</themekt>
# 				<themekey>AASG</themekey>
# 				<themekey>Association of State Geologists</themekey>
# 				<themekey>Geology, Geophysics, and Geochemistry Science Center</themekey>
# 				<themekey>GGGSC</themekey>
# 				<themekey>Earth Mapping Resources Initiative</themekey>
# 				<themekey>EarthMRI</themekey>
# 				<themekey>horizontal magnetic gradiometry</themekey>
# 				<themekey>airborne geophysical survey</themekey>
# 				<themekey>Mineral Resources Program</themekey>
# 				<themekey>MRP</themekey>
# 				<themekey>Earthquake Hazards Program</themekey>
# 				<themekey>EHP</themekey>
# 				<themekey>National Cooperative Geologic Mapping Program</themekey>
# 				<themekey>NCGMP</themekey>
# 				<themekey>U.S. Geological Survey</themekey>
# 				<themekey>USGS</themekey>
# 			</theme>
# 			<theme>
# 				<themekt>ISO 19115 Topic Category</themekt>
# 				<themekey>geoscientificInformation</themekey>
# 				<themekey>economy</themekey>
# 			</theme>
# 			<place>
# 				<placekt>Geographic Names Information System (GNIS)</placekt>
# 				<placekey>Ballard County</placekey>
# 				<placekey>Carlisle County</placekey>
# 				<placekey>Jackson County</placekey>
# 				<placekey>Jefferson County</placekey>
# 				<placekey>Johnson County</placekey>
# 				<placekey>Massac County</placekey>
# 				<placekey>Alexander County</placekey>
# 				<placekey>McCracken County</placekey>
# 				<placekey>Perry County</placekey>
# 				<placekey>Pulaski County</placekey>
# 				<placekey>Randolph County</placekey>
# 				<placekey>St. Clair County</placekey>
# 				<placekey>Union County</placekey>
# 				<placekey>Washington County</placekey>
# 				<placekey>Williamson County</placekey>
# 				<placekey>Franklin County</placekey>
# 				<placekey>Bollinger County</placekey>
# 				<placekey>Cape Girardeau County</placekey>
# 				<placekey>Mississippi County</placekey>
# 				<placekey>New Madrid County</placekey>
# 				<placekey>Perry County</placekey>
# 				<placekey>Scott County</placekey>
# 				<placekey>Stoddard County</placekey>
# 				<placekey>Cape Girardeau</placekey>
# 			</place>
# 			<place>
# 				<placekt>Common geographic areas</placekt>
# 				<placekey>United States</placekey>
# 				<placekey>Missouri</placekey>
# 				<placekey>Illinois</placekey>
# 				<placekey>Kentucky</placekey>
# 			</place>
# 			<place>
# 				<placekt>Types</placekt>
# 				<placekey>Downloadable</placekey>
# 				<placekey>GeoTIFF</placekey>
# 				<placekey>Map Service</placekey>
# 				<placekey>Rasters</placekey>
# 			</place>
# 		</keywords>
# 		<accconst>None. Please see 'Distribution Info' for details</accconst>
# 		<useconst>Any use of trade, firm, or product names is for descriptive purposes only and does not imply endorsement by the U.S. Government. Although these data have been processed successfully on a computer system at the U.S. Geological Survey (USGS), no warranty expressed or implied is made regarding the display or utility of the data for other purposes, nor on all computer systems, nor shall the act of distribution constitute any such warranty. The USGS or the U.S. Government shall not be held liable for improper or incorrect use of the data described and/or contained herein.</useconst>
# 		<ptcontac>
# 			<cntinfo>
# 				<cntperp>
# 					<cntper>Anne E. McCafferty</cntper>
# 					<cntorg>U.S. Geological Survey</cntorg>
# 				</cntperp>
# 				<cntpos>Research Geophysicist</cntpos>
# 				<cntaddr>
# 					<addrtype>mailing and physical</addrtype>
# 					<address>Box 25046, Mail Stop 973, Denver Federal Center, W 6th Ave and Kipling St</address>
# 					<city>Denver</city>
# 					<state>CO</state>
# 					<postal>80225</postal>
# 					<country>USA</country>
# 				</cntaddr>
# 				<cntvoice>303.236.1397</cntvoice>
# 				<cntemail>anne@usgs.gov</cntemail>
# 			</cntinfo>
# 		</ptcontac>
# 		<datacred>This release of the dataset was funded by the U.S. Geological Survey Earth Mapping Resource Initiative and the Missouri Department of Natural Resources Geological Survey.  The authors would like to thank the Missouri Geological Survey for providing funding for this study.</datacred>
# 		<native>The data were generated using commercially available software including Geosoft Oasis Montaj v. 9.9.1 and ESRI ArcMap v.10.8.1.</native>
# 	</idinfo>
# 	<dataqual>
# 		<attracc>
# 			<attraccr>Daily quality control of raw radiometric and magnetic data was performed by the contractor and is described in the contractor report. Further quality control measures occurred post flight by the contractor and USGS scientist-in-charge before approval and acceptance of the final data. The data have been peer reviewed and compared with related ancillary data.</attraccr>
# 		</attracc>
# 		<logic>Data were visually inspected for reasonableness and spatial consistency.</logic>
# 		<complete>Data set is considered complete for the information presented, as described in the abstract. Users are advised to read the rest of the metadata record carefully for additional details. All data as part of this collection were included in this data release for the region and time period specified in this metadata.</complete>
# 		<posacc>
# 			<horizpa>
# 				<horizpar>Field quality control and assurance procedures were undertaken by the Terraquest field crew and are described in the contractor's report included with this data release.</horizpar>
# 			</horizpa>
# 			<vertacc>
# 				<vertaccr>Field quality control and assurance procedures were undertaken by the Terraquest field crew and are described in the contractor's report included with this data release.</vertaccr>
# 			</vertacc>
# 		</posacc>
# 		<lineage>
# 			<procstep>
# 				<procdesc>The airborne survey was flown under contract to the U.S. Geological Survey by Terraquest, Ltd from March 16, 2021 to July 13, 2021. The magnetic data were acquired with 3 cesium vapor magnetometers. The radiometric data were acquired with radiation Solutions RS-500 gamma ray spectrometer. Data were collected along north-south flight lines spaced 250 meters (m) apart with east-west tie lines flown every 3500 m. A mean terrain clearance of 100 m was maintained; in some areas safety dictated a higher elevation. A total of 64,227.3 line-kilometers (km) of data were collected.</procdesc>
# 				<procdate>20210713</procdate>
# 			</procstep>
# 			<procstep>
# 				<procdesc>1) Lag Correction of Total Magnetic Field, 2) Diurnal Data and diurnal correction of Total Magnetic Field, 3) Total Magnetic Field Tie-Traverse Line Intersection Leveling, 4) Total Magnetic Field Micro-leveling, 5) Calculated Vertical Derivative, 6) Measured Horizontal Gradients, 7) Reconstructed Total Magnetic Field (RTF), 8) Data Gridding, 9) Magnetic Database Output</procdesc>
# 				<procdate>20211115</procdate>
# 			</procstep>
# 			<procstep>
# 				<procdesc>Final data and contractor's report were accepted and received by USGS from Terraquest Ltd</procdesc>
# 				<procdate>20211115</procdate>
# 			</procstep>
# 			<procstep>
# 				<procdesc>Final data were exported to CSV-format and NetCDF to meet open data requirements.</procdesc>
# 				<procdate>20220404</procdate>
# 			</procstep>
# 			<procstep>
# 				<procdesc>Shapefile of the locations of the airborne geophysical survey flightlines</procdesc>
# 				<procdate>20220404</procdate>
# 			</procstep>
# 		</lineage>
# 	</dataqual>
# 	<spdoinfo>
# 		<direct>Raster</direct>
# 	</spdoinfo>
# 	<spref>
# 		<horizsys>
# 			<planar>
# 				<gridsys>
# 					<gridsysn>Universal Transverse Mercator</gridsysn>
# 					<utm>
# 						<utmzone>16</utmzone>
# 						<transmer>
# 							<sfctrmer>0.9996</sfctrmer>
# 							<longcm>-81</longcm>
# 							<latprjo>0</latprjo>
# 							<feast>500000</feast>
# 							<fnorth>0</fnorth>
# 						</transmer>
# 					</utm>
# 				</gridsys>
# 				<planci>
# 					<plance>coordinate pair</plance>
# 					<coordrep>
# 						<absres>0.6096</absres>
# 						<ordres>0.6096</ordres>
# 					</coordrep>
# 					<plandu>meter</plandu>
# 				</planci>
# 			</planar>
# 			<geodetic>
# 				<horizdn>World Geodetic System (WGS) 1984</horizdn>
# 				<ellips>WGS_1984</ellips>
# 				<semiaxis>6378137</semiaxis>
# 				<denflat>298.2572236</denflat>
# 			</geodetic>
# 		</horizsys>
# 	</spref>
# 	<eainfo>
# 		<detailed>
# 			<enttyp>
# 				<enttypl>TotalMagneticIntensity.jpg</enttypl>
# 				<enttypd>Image of total magnetic intensity</enttypd>
# 				<enttypds>U.S. Geological Survey</enttypds>
# 			</enttyp>
# 			<attr>
# 				<attrlabl>Value</attrlabl>
# 				<attrdef>Unique numeric values contained in each raster cell.</attrdef>
# 				<attrdefs>U.S. Geological Survey</attrdefs>
# 				<attrdomv>
# 					<rdom>
# 						<rdommin>0</rdommin>
# 						<rdommax>255</rdommax>
# 					</rdom>
# 				</attrdomv>
# 			</attr>
# 		</detailed>
# 		<detailed>
# 			<enttyp>
# 				<enttypl>Gap_TF3ANM.tif</enttypl>
# 				<enttypd>Raster geospatial data file.</enttypd>
# 				<enttypds>Producer Defined</enttypds>
# 			</enttyp>
# 			<attr>
# 				<attrlabl>nanoTesla</attrlabl>
# 				<attrdef>Unique numeric values contained in each raster cell.</attrdef>
# 				<attrdefs>total magnetic intensity in nT</attrdefs>
# 				<attrdomv>
# 					<rdom>
# 						<rdommin>-675.17901611328</rdommin>
# 						<rdommax>2774.9182128906</rdommax>
# 						<attrunit>nT</attrunit>
# 					</rdom>
# 				</attrdomv>
# 			</attr>
# 		</detailed>
# 		<detailed>
# 			<enttyp>
# 				<enttypl>MO20F0196_USGS_GAP_MagneticFlightLineData.csv</enttypl>
# 				<enttypd>Dataset containing minimally processed (raw) magnetic data.</enttypd>
# 				<enttypds>U.S. Geological Survey</enttypds>
# 			</enttyp>
# 			<attr>
# 				<attrlabl>ALT</attrlabl>
# 				<attrdef>WGS84 Altitude (metres AMSL)</attrdef>
# 				<attrdefs>Terraquest, Ltd</attrdefs>
# 				<attrdomv>
# 						<rdom>
# 						<rdommin>152.2</rdommin>
# 						<rdommax>393.1</rdommax>
# 						<attrunit>m</attrunit>
# 					</rdom>
# 					</attrdomv>
# 			</attr><attr>
# 				<attrlabl>AZIMUTH</attrlabl>
# 				<attrdef>Flight Line direction (ranged</attrdef>
# 				<attrdefs>Terraquest, Ltd</attrdefs>
# 				<attrdomv>
# 						<rdom>
# 						<rdommin>-7.034545811279713e-05</rdommin>
# 						<rdommax>360.00006438998673</rdommax>
# 						<attrunit>deg</attrunit>
# 					</rdom>
# 					</attrdomv>
# 			</attr><attr>
# 				<attrlabl>DATE</attrlabl>
# 				<attrdef>Flight Date (DD/MM/YYYY format - ASCII)</attrdef>
# 				<attrdefs>Terraquest, Ltd</attrdefs>
# 				<attrdomv>
# 						<rdom>
# 						<rdommin>2021.2027397260274</rdommin>
# 						<rdommax>9999.0</rdommax>
# 						<attrunit>yyyymmdd</attrunit>
# 					</rdom>
# 					</attrdomv>
# 			</attr><attr>
# 				<attrlabl>DIUCON</attrlabl>
# 				<attrdef>Consolidated Diurnal - using tied-in Backup Diurnal where required</attrdef>
# 				<attrdefs>Terraquest, Ltd</attrdefs>
# 				<attrdomv>
# 						<rdom>
# 						<rdommin>51121.95400035512</rdommin>
# 						<rdommax>51187.86999974233</rdommax>
# 						<attrunit>nT</attrunit>
# 					</rdom>
# 					</attrdomv>
# 			</attr><attr>
# 				<attrlabl>DIUEDIT</attrlabl>
# 				<attrdef>Base Station Diurnal data (nT) -edited/de-spiked</attrdef>
# 				<attrdefs>Terraquest, Ltd</attrdefs>
# 				<attrdomv>
# 						<rdom>
# 						<rdommin>51121.95400035512</rdommin>
# 						<rdommax>51589.95637066768</rdommax>
# 						<attrunit>nT</attrunit>
# 					</rdom>
# 					</attrdomv>
# 			</attr><attr>
# 				<attrlabl>DIUEDIT2</attrlabl>
# 				<attrdef>Backup Base Station Diurnal data (nT) -edited/de-spiked (if used)</attrdef>
# 				<attrdefs>Terraquest, Ltd</attrdefs>
# 				<attrdomv>
# 						<rdom>
# 						<rdommin>51016.36482638655</rdommin>
# 						<rdommax>51201.7437218853</rdommax>
# 						<attrunit>nT</attrunit>
# 					</rdom>
# 					</attrdomv>
# 			</attr><attr>
# 				<attrlabl>DIURNAL</attrlabl>
# 				<attrdef>Base Station Diurnal data (nT) -measured</attrdef>
# 				<attrdefs>Terraquest, Ltd</attrdefs>
# 				<attrdomv>
# 						<rdom>
# 						<rdommin>50470.17693928254</rdommin>
# 						<rdommax>51589.95637066768</rdommax>
# 						<attrunit>nT</attrunit>
# 					</rdom>
# 					</attrdomv>
# 			</attr><attr>
# 				<attrlabl>DIURNAL2</attrlabl>
# 				<attrdef>Backup Base Station Diurnal data (nT) -measured</attrdef>
# 				<attrdefs>Terraquest, Ltd</attrdefs>
# 				<attrdomv>
# 						<rdom>
# 						<rdommin>0.104939121256272</rdommin>
# 						<rdommax>56176.57501070219</rdommax>
# 						<attrunit>nT</attrunit>
# 					</rdom>
# 					</attrdomv>
# 			</attr><attr>
# 				<attrlabl>DTMFNL</attrlabl>
# 				<attrdef>Final, corrected Digital Terrain Model  (m AMSL)</attrdef>
# 				<attrdefs>Terraquest, Ltd</attrdefs>
# 				<attrdomv>
# 						<rdom>
# 						<rdommin>16.994124314134982</rdommin>
# 						<rdommax>291.7611925657331</rdommax>
# 						<attrunit>m</attrunit>
# 					</rdom>
# 					</attrdomv>
# 			</attr><attr>
# 				<attrlabl>FID</attrlabl>
# 				<attrdef>Fiducial (UTC day-seconds)</attrdef>
# 				<attrdefs>Terraquest, Ltd</attrdefs>
# 				<attrdomv>
# 						<rdom>
# 						<rdommin>38367.80001458526</rdommin>
# 						<rdommax>91681.40002070367</rdommax>
# 						<attrunit>id</attrunit>
# 					</rdom>
# 					</attrdomv>
# 			</attr><attr>
# 				<attrlabl>FLIGHT</attrlabl>
# 				<attrdef>Flight Number</attrdef>
# 				<attrdefs>Terraquest, Ltd</attrdefs>
# 				<attrdomv>
# 						<rdom>
# 						<rdommin>13.0</rdommin>
# 						<rdommax>96.0</rdommax>
# 						<attrunit>n/a</attrunit>
# 					</rdom>
# 					</attrdomv>
# 			</attr><attr>
# 				<attrlabl>HGEWFNL</attrlabl>
# 				<attrdef>Final, measured East-West Magnetic gradient (nT/m)</attrdef>
# 				<attrdefs>Terraquest, Ltd</attrdefs>
# 				<attrdomv>
# 						<rdom>
# 						<rdommin>-32.695221227227094</rdommin>
# 						<rdommax>29.543117709894766</rdommax>
# 						<attrunit>nT/m</attrunit>
# 					</rdom>
# 					</attrdomv>
# 			</attr><attr>
# 				<attrlabl>HGNSFNL</attrlabl>
# 				<attrdef>Final, measured North-South Magnetic gradient (nT/m)</attrdef>
# 				<attrdefs>Terraquest, Ltd</attrdefs>
# 				<attrdomv>
# 						<rdom>
# 						<rdommin>-14.266383609548317</rdommin>
# 						<rdommax>18.791292674510498</rdommax>
# 						<attrunit>nT/m</attrunit>
# 					</rdom>
# 					</attrdomv>
# 			</attr><attr>
# 				<attrlabl>IGRF_DEC</attrlabl>
# 				<attrdef>IGRF Declination (Calculation date [2020 Coefficients]</attrdef>
# 				<attrdefs>Terraquest, Ltd</attrdefs>
# 				<attrdomv>
# 						<rdom>
# 						<rdommin>-2.6538000191718356</rdommin>
# 						<rdommax>-1.7458</rdommax>
# 						<attrunit>deg</attrunit>
# 					</rdom>
# 					</attrdomv>
# 			</attr><attr>
# 				<attrlabl>IGRF_INC</attrlabl>
# 				<attrdef>IGRF Inclination (Calculation date [2020 Coefficients]</attrdef>
# 				<attrdefs>Terraquest, Ltd</attrdefs>
# 				<attrdomv>
# 						<rdom>
# 						<rdommin>64.91329998054505</rdommin>
# 						<rdommax>66.08320003214628</rdommax>
# 						<attrunit>deg</attrunit>
# 					</rdom>
# 					</attrdomv>
# 			</attr><attr>
# 				<attrlabl>IGRF_TF</attrlabl>
# 				<attrdef>IGRF Total Field (Calculation date [2020 Coefficients]</attrdef>
# 				<attrdefs>Terraquest, Ltd</attrdefs>
# 				<attrdomv>
# 						<rdom>
# 						<rdommin>50774.05899336586</rdommin>
# 						<rdommax>51573.83920643823</rdommax>
# 						<attrunit>nT</attrunit>
# 					</rdom>
# 					</attrdomv>
# 			</attr><attr>
# 				<attrlabl>JULIAN</attrlabl>
# 				<attrdef>Year+Julian Day</attrdef>
# 				<attrdefs>Terraquest, Ltd</attrdefs>
# 				<attrdomv>
# 						<rdom>
# 						<rdommin>202175.0</rdommin>
# 						<rdommax>2021194.0</rdommax>
# 						<attrunit>Year+Julian Day</attrunit>
# 					</rdom>
# 					</attrdomv>
# 			</attr><attr>
# 				<attrlabl>LAT</attrlabl>
# 				<attrdef>Latitude (decimal degrees)</attrdef>
# 				<attrdefs>Terraquest, Ltd</attrdefs>
# 				<attrdomv>
# 						<rdom>
# 						<rdommin>36.83041508577423</rdommin>
# 						<rdommax>38.29528422465964</rdommax>
# 						<attrunit>dega</attrunit>
# 					</rdom>
# 					</attrdomv>
# 			</attr><attr>
# 				<attrlabl>LINE</attrlabl>
# 				<attrdef>Line Number (ASCII; Prefix L</attrdef>
# 				<attrdefs>Terraquest, Ltd</attrdefs>
# 				<attrdomv>
# 						<rdom>
# 						<rdommin>1e+32</rdommin>
# 						<rdommax>-1e+32</rdommax>
# 						<attrunit>id</attrunit>
# 					</rdom>
# 					</attrdomv>
# 			</attr><attr>
# 				<attrlabl>LON</attrlabl>
# 				<attrdef>Longitude (decimal degrees)</attrdef>
# 				<attrdefs>Terraquest, Ltd</attrdefs>
# 				<attrdomv>
# 						<rdom>
# 						<rdommin>-89.95097715657224</rdommin>
# 						<rdommax>-88.83967198411617</rdommax>
# 						<attrunit>dega</attrunit>
# 					</rdom>
# 					</attrdomv>
# 			</attr><attr>
# 				<attrlabl>RADAR</attrlabl>
# 				<attrdef>Radar Altimeter (metres AGL)</attrdef>
# 				<attrdefs>Terraquest, Ltd</attrdefs>
# 				<attrdomv>
# 						<rdom>
# 						<rdommin>59.601561401367185</rdommin>
# 						<rdommax>227.20222607421874</rdommax>
# 						<attrunit>m</attrunit>
# 					</rdom>
# 					</attrdomv>
# 			</attr><attr>
# 				<attrlabl>RADFNL</attrlabl>
# 				<attrdef>Radar Altimeter corrected for system lag (metres AGL)</attrdef>
# 				<attrdefs>Terraquest, Ltd</attrdefs>
# 				<attrdomv>
# 						<rdom>
# 						<rdommin>59.15603038641735</rdommin>
# 						<rdommax>226.30629546657067</rdommax>
# 						<attrunit>m</attrunit>
# 					</rdom>
# 					</attrdomv>
# 			</attr><attr>
# 				<attrlabl>TF1CMP</attrlabl>
# 				<attrdef>Raw, Compensated TMI (Left WingTip, nT)</attrdef>
# 				<attrdefs>Terraquest, Ltd</attrdefs>
# 				<attrdomv>
# 						<rdom>
# 						<rdommin>42078.1597</rdommin>
# 						<rdommax>54049.92578125</rdommax>
# 						<attrunit>nT</attrunit>
# 					</rdom>
# 					</attrdomv>
# 			</attr><attr>
# 				<attrlabl>TF1CMPEDIT</attrlabl>
# 				<attrdef>Edited (de-Spiked), Compensated TMI (Left WingTip, nT)</attrdef>
# 				<attrdefs>Terraquest, Ltd</attrdefs>
# 				<attrdomv>
# 						<rdom>
# 						<rdommin>50163.4140625</rdommin>
# 						<rdommax>54049.92578125</rdommax>
# 						<attrunit>nT</attrunit>
# 					</rdom>
# 					</attrdomv>
# 			</attr><attr>
# 				<attrlabl>TF1UNC</attrlabl>
# 				<attrdef>Raw, Uncompensated TMI (Left WingTip, nT)</attrdef>
# 				<attrdefs>Terraquest, Ltd</attrdefs>
# 				<attrdomv>
# 						<rdom>
# 						<rdommin>42053.23046875</rdommin>
# 						<rdommax>54038.296875</rdommax>
# 						<attrunit>nT</attrunit>
# 					</rdom>
# 					</attrdomv>
# 			</attr><attr>
# 				<attrlabl>TF2CMP</attrlabl>
# 				<attrdef>Raw, Compensated TMI (Right WingTip, nT)</attrdef>
# 				<attrdefs>Terraquest, Ltd</attrdefs>
# 				<attrdomv>
# 						<rdom>
# 						<rdommin>50179.30078125</rdommin>
# 						<rdommax>53715.78515625</rdommax>
# 						<attrunit>nT</attrunit>
# 					</rdom>
# 					</attrdomv>
# 			</attr><attr>
# 				<attrlabl>TF2CMPEDIT</attrlabl>
# 				<attrdef>Edited (de-Spiked), Compensated TMI (Right WingTip, nT)</attrdef>
# 				<attrdefs>Terraquest, Ltd</attrdefs>
# 				<attrdomv>
# 						<rdom>
# 						<rdommin>50179.30078125</rdommin>
# 						<rdommax>53715.78515625</rdommax>
# 						<attrunit>nT</attrunit>
# 					</rdom>
# 					</attrdomv>
# 			</attr><attr>
# 				<attrlabl>TF2UNC</attrlabl>
# 				<attrdef>Raw, Uncompensated TMI (Right WingTip, nT)</attrdef>
# 				<attrdefs>Terraquest, Ltd</attrdefs>
# 				<attrdomv>
# 						<rdom>
# 						<rdommin>50166.77734375</rdommin>
# 						<rdommax>53710.0390625</rdommax>
# 						<attrunit>nT</attrunit>
# 					</rdom>
# 					</attrdomv>
# 			</attr><attr>
# 				<attrlabl>TF3ANM</attrlabl>
# 				<attrdef>Anomalous TMI (IGRF corrected, nT)</attrdef>
# 				<attrdefs>Terraquest, Ltd</attrdefs>
# 				<attrdomv>
# 						<rdom>
# 						<rdommin>-683.8045732156461</rdommin>
# 						<rdommax>2840.466988677508</rdommax>
# 						<attrunit>nT</attrunit>
# 					</rdom>
# 					</attrdomv>
# 			</attr><attr>
# 				<attrlabl>TF3CMP</attrlabl>
# 				<attrdef>Raw, Compensated TMI (Tail, nT) - Principal Magnetometer</attrdef>
# 				<attrdefs>Terraquest, Ltd</attrdefs>
# 				<attrdomv>
# 						<rdom>
# 						<rdommin>50195.15625</rdommin>
# 						<rdommax>53841.99609375</rdommax>
# 						<attrunit>nT</attrunit>
# 					</rdom>
# 					</attrdomv>
# 			</attr><attr>
# 				<attrlabl>TF3CMPEDIT</attrlabl>
# 				<attrdef>Edited (de-Spiked), Compensated TMI (Tail, nT) - Principal Magnetometer</attrdef>
# 				<attrdefs>Terraquest, Ltd</attrdefs>
# 				<attrdomv>
# 						<rdom>
# 						<rdommin>50195.15625</rdommin>
# 						<rdommax>53841.99609375</rdommax>
# 						<attrunit>nT</attrunit>
# 					</rdom>
# 					</attrdomv>
# 			</attr><attr>
# 				<attrlabl>TF3DIU</attrlabl>
# 				<attrdef>Diurnal corrected Tail TMI (nT)</attrdef>
# 				<attrdefs>Terraquest, Ltd</attrdefs>
# 				<attrdomv>
# 						<rdom>
# 						<rdommin>50208.47791175082</rdommin>
# 						<rdommax>53863.16590563662</rdommax>
# 						<attrunit>nT</attrunit>
# 					</rdom>
# 					</attrdomv>
# 			</attr><attr>
# 				<attrlabl>TF3FNL</attrlabl>
# 				<attrdef>Final (micro-levelled) TMI (nT)</attrdef>
# 				<attrdefs>Terraquest, Ltd</attrdefs>
# 				<attrdomv>
# 						<rdom>
# 						<rdommin>50203.813361602384</rdommin>
# 						<rdommax>53862.01928863233</rdommax>
# 						<attrunit>nT</attrunit>
# 					</rdom>
# 					</attrdomv>
# 			</attr><attr>
# 				<attrlabl>TF3LVL</attrlabl>
# 				<attrdef>Tie-line intersection levelled TMI (nT)</attrdef>
# 				<attrdefs>Terraquest, Ltd</attrdefs>
# 				<attrdomv>
# 						<rdom>
# 						<rdommin>50208.03743026934</rdommin>
# 						<rdommax>53863.311313044025</rdommax>
# 						<attrunit>nT</attrunit>
# 					</rdom>
# 					</attrdomv>
# 			</attr><attr>
# 				<attrlabl>TF3UNC</attrlabl>
# 				<attrdef>Raw, Uncompensated TMI (Tail, nT) - Principal Magnetometer</attrdef>
# 				<attrdefs>Terraquest, Ltd</attrdefs>
# 				<attrdomv>
# 						<rdom>
# 						<rdommin>50188.890625</rdommin>
# 						<rdommax>53834.140625</rdommax>
# 						<attrunit>nT</attrunit>
# 					</rdom>
# 					</attrdomv>
# 			</attr><attr>
# 				<attrlabl>TIME</attrlabl>
# 				<attrdef>UTC TIME (hh</attrdef>
# 				<attrdefs>Terraquest, Ltd</attrdefs>
# 				<attrdomv>
# 						<rdom>
# 						<rdommin>10.657722226273682</rdommin>
# 						<rdommax>25.467055561306577</rdommax>
# 						<attrunit>hh:mm:ss.ss</attrunit>
# 					</rdom>
# 					</attrdomv>
# 			</attr><attr>
# 				<attrlabl>VMX</attrlabl>
# 				<attrdef>Fluxgate X component (nT)</attrdef>
# 				<attrdefs>Terraquest, Ltd</attrdefs>
# 				<attrdomv>
# 						<rdom>
# 						<rdommin>-51599.0625</rdommin>
# 						<rdommax>-15652.5712890625</rdommax>
# 						<attrunit>nT</attrunit>
# 					</rdom>
# 					</attrdomv>
# 			</attr><attr>
# 				<attrlabl>VMY</attrlabl>
# 				<attrdef>Fluxgate Y component (nT)</attrdef>
# 				<attrdefs>Terraquest, Ltd</attrdefs>
# 				<attrdomv>
# 						<rdom>
# 						<rdommin>-34583.1328125</rdommin>
# 						<rdommax>17154.3359375</rdommax>
# 						<attrunit>nT</attrunit>
# 					</rdom>
# 					</attrdomv>
# 			</attr><attr>
# 				<attrlabl>VMZ</attrlabl>
# 				<attrdef>Fluxgate Z component (nT)</attrdef>
# 				<attrdefs>Terraquest, Ltd</attrdefs>
# 				<attrdomv>
# 						<rdom>
# 						<rdommin>-48452.1484375</rdommin>
# 						<rdommax>49264.515625</rdommax>
# 						<attrunit>nT</attrunit>
# 					</rdom>
# 					</attrdomv>
# 			</attr><attr>
# 				<attrlabl>X_UTM_TRIM</attrlabl>
# 				<attrdef>UTM Easting - WGS84, UTM Zone 16N (metres) - trimmed for line overlap</attrdef>
# 				<attrdefs>Terraquest, Ltd</attrdefs>
# 				<attrdomv>
# 						<rdom>
# 						<rdommin>236824.4340386539</rdommin>
# 						<rdommax>335993.89589584223</rdommax>
# 						<attrunit>m</attrunit>
# 					</rdom>
# 					</attrdomv>
# 			</attr><attr>
# 				<attrlabl>X_UTM_WIN</attrlabl>
# 				<attrdef>UTM Easting - WGS84, UTM Zone 16N (metres)</attrdef>
# 				<attrdefs>Terraquest, Ltd</attrdefs>
# 				<attrdomv>
# 						<rdom>
# 						<rdommin>236824.4340386539</rdommin>
# 						<rdommax>335993.89589584223</rdommax>
# 						<attrunit>m</attrunit>
# 					</rdom>
# 					</attrdomv>
# 			</attr><attr>
# 				<attrlabl>Y_UTM_TRIM</attrlabl>
# 				<attrdef>UTM Northing - WGS84, UTM Zone 16N (metres) - trimmed for line overlap</attrdef>
# 				<attrdefs>Terraquest, Ltd</attrdefs>
# 				<attrdomv>
# 						<rdom>
# 						<rdommin>4080094.457927594</rdommin>
# 						<rdommax>4240292.028284814</rdommax>
# 						<attrunit>m</attrunit>
# 					</rdom>
# 					</attrdomv>
# 			</attr><attr>
# 				<attrlabl>Y_UTM_WIN</attrlabl>
# 				<attrdef>UTM Northing - WGS84, UTM Zone 16N (metres)</attrdef>
# 				<attrdefs>Terraquest, Ltd</attrdefs>
# 				<attrdomv>
# 						<rdom>
# 						<rdommin>4080094.457927594</rdommin>
# 						<rdommax>4240292.028284814</rdommax>
# 						<attrunit>m</attrunit>
# 					</rdom>
# 					</attrdomv>
# 			</attr>
# 		</detailed>
# 		<overview>
# 			<eaover>Survey report from Terraquest. This report describes the survey parameters, field operations, and quality control procedures used to produce the magnetic and radiometric data.</eaover>
# 			<eadetcit>https://doi.org/10.5066/P9TK8KMM</eadetcit>
# 		</overview>
# 	</eainfo>
# 	<distinfo>
# 		<distrib>
# 			<cntinfo>
# 				<cntorgp>
# 					<cntorg>U.S. Geological Survey - ScienceBase</cntorg>
# 				</cntorgp>
# 				<cntaddr>
# 					<addrtype>mailing and physical</addrtype>
# 					<address>Denver Federal Center, Building 810, Mail Stop 302</address>
# 					<city>Denver</city>
# 					<state>CO</state>
# 					<postal>80225</postal>
# 					<country>USA</country>
# 				</cntaddr>
# 				<cntvoice>1-888-275-8747</cntvoice>
# 				<cntemail>sciencebase@usgs.gov</cntemail>
# 			</cntinfo>
# 		</distrib>
# 		<resdesc>https://www.sciencebase.gov/catalog/item/62434c50d34e22d73748d366</resdesc>
# 		<distliab>Unless otherwise stated, all data, metadata and related materials are considered to satisfy the quality standards relative to the purpose for which the data were collected. Although these data and associated metadata have been reviewed for accuracy and completeness and approved for release by the U.S. Geological Survey (USGS), no warranty expressed or implied is made regarding the display or utility of the data for other purposes, nor on all computer systems, nor shall the act of distribution constitute any such warranty.</distliab>
# 		<stdorder>
# 			<digform>
# 				<digtinfo>
# 					<formname>CSV</formname>
# 					<formvern>1</formvern>
# 					<formspec>MO20F0196_USGS_GAP_MagneticFlightLineData.csv</formspec>
# 					<formcont>Dataset containing minimally processed (raw) magnetic data.</formcont>
# 					<filedec>no compression applied</filedec>
# 					<transize>5120</transize>
# 				</digtinfo>
# 				<digtopt>
# 					<onlinopt>
# 						<computer>
# 							<networka>
# 								<networkr>https://www.sciencebase.gov/catalog/file/get/62434c50d34e22d73748d366?f=__disk__68%2F98%2Fdb%2F6898db1da809a774f7ed36d4d7a82a6afd517465</networkr>
# 								<networkr>https://doi.org/10.5066/P9TK8KMM</networkr>
# 								<networkr>https://www.sciencebase.gov/catalog/item/62434c50d34e22d73748d366</networkr>
# 							</networka>
# 						</computer>
# 					</onlinopt>
# 				</digtopt>
# 			</digform>
# 			<digform>
# 				<digtinfo>
# 					<formname>JPG</formname>
# 					<formvern>1</formvern>
# 					<formspec>TotalMagneticIntensity.jpg</formspec>
# 					<formcont>Image of total magnetic intensity</formcont>
# 					<filedec>no compression applied</filedec>
# 					<transize>2.82</transize>
# 				</digtinfo>
# 				<digtopt>
# 					<onlinopt>
# 						<computer>
# 							<networka>
# 								<networkr>https://www.sciencebase.gov/catalog/file/get/62434c50d34e22d73748d366?f=__disk__20%2Fc9%2F37%2F20c93713022bcbe655c26bbac2ccca0dd3f3221a</networkr>
# 							</networka>
# 						</computer>
# 					</onlinopt>
# 				</digtopt>
# 			</digform>
# 			<digform>
# 				<digtinfo>
# 					<formname>GeoTIFF</formname>
# 					<formvern>1</formvern>
# 					<formspec>Gap_TF3ANM.tif</formspec>
# 					<formcont> Georeferenced Tag Image File Format- Georeferenced image of total magnetic intensity</formcont>
# 					<filedec>no compression applied</filedec>
# 					<transize>25.01</transize>
# 				</digtinfo>
# 				<digtopt>
# 					<onlinopt>
# 						<computer>
# 							<networka>
# 								<networkr> https://www.sciencebase.gov/catalog/file/get/62434c50d34e22d73748d366?f=__disk__ab%2F63%2Fd3%2Fab63d3d78ee5dc5c9dc7552d6d4fdbbaca9fb9a2</networkr>
# 							</networka>
# 						</computer>
# 					</onlinopt>
# 				</digtopt>
# 			</digform>
# 			<digform>
# 				<digtinfo>
# 					<formname>JSON</formname>
# 					<formvern>1</formvern>
# 					<formspec>MO20F0196_USGS_GAP_MagneticFlightLineData.json</formspec>
# 					<formcont>JSON file containing data dictionary describing the attribute information associated with the magnetic data.</formcont>
# 					<filedec>no compression applied</filedec>
# 					<transize>0.011</transize>
# 				</digtinfo>
# 				<digtopt>
# 					<onlinopt>
# 						<computer>
# 							<networka>
# 								<networkr>https://www.sciencebase.gov/catalog/file/get/62434c50d34e22d73748d366?f=__disk__20%2Fc9%2F37%2F20c93713022bcbe655c26bbac2ccca0dd3f3221a</networkr>
# 							</networka>
# 						</computer>
# 					</onlinopt>
# 				</digtopt>
# 			</digform>
# 			<fees>none</fees>
# 		</stdorder>
# 	</distinfo>
# 	<metainfo>
# 		<metd>20220526</metd>
# 		<metc>
# 			<cntinfo>
# 				<cntperp>
# 					<cntper>Dylan M Connell</cntper>
# 					<cntorg>U.S. Geological Survey</cntorg>
# 				</cntperp>
# 				<cntpos>Geophysicist</cntpos>
# 				<cntaddr>
# 					<addrtype>mailing and physical</addrtype>
# 					<address>Box 25046, Mail Stop 964, Denver Federal Center, W 6th Ave and Kipling St</address>
# 					<city>Denver</city>
# 					<state>CO</state>
# 					<postal>80225</postal>
# 					<country>USA</country>
# 				</cntaddr>
# 				<cntvoice>n/a</cntvoice>
# 				<cntemail>dconnell@usgs.gov</cntemail>
# 				<cntemail>dconnell@usgs.gov</cntemail>
# 			</cntinfo>
# 		</metc>
# 		<metstdn>Content Standard for Digital Geospatial Metadata</metstdn>
# 		<metstdv>FGDC-STD-001-1998</metstdv>
# 	</metainfo>
# </metadata>

# %%
#login to ScienceBase
sb = pysb.SbSession()
username = input("Username:  ")
sb.loginc(str(username))
#Check to see if login is successful
sb.is_logged_in()
#Get the ScienceBase Login session info
sb.get_session_info()
# Out:
# Username:  pbrown@usgs.gov
# ········
# {'fullDisplayName': 'Philip J Brown II [pbrown@usgs.gov]',
#  'isLoggedIn': True,
#  'jossoSessionId': '00FA4755F611A9275FD29E594DAE4648',
#  'displayName': 'Philip J Brown II',
#  'email': 'pbrown@usgs.gov',
#  'username': 'pbrown@usgs.gov'}

# %%
# Now lets get the item - be sure to use the correct catalog number!!!
catNum = '62434c50d34e22d73748d366'
item_json = sb.get_item(catNum)
#print ("Public Item: \n\t" + str(item_json))
print(json.dumps(item_json, indent=2, sort_keys=True))
# Out:
# {
#   "alternateTitles": [
#     ""
#   ],
#   "body": "Airborne magnetic gradiometry data along the tie and flight lines are provided here in CSV (Comma Separated Value) format along with a GeoTIFF grid of the total magnetic intensity (TMI) in nanoTeslas.&nbsp; Along with the data provided on this child page, a report in PDF format by the airborne contractor that describes the technical details of the data collection, reduction and processing procedures and a zip file that contains the contractor's deliverable products (Geosoft databases and grids) for the magnetic and radiometric survey is available on the parent page (https://doi.org/10.5066/P9TK8KMM).<br>\n<br>\nReferences Cited:<br>\n<br>\nMcCafferty, A.E., and Johnson, M.R., 2019, Airborne magnetic and radiometric survey, southeast Missouri and western Illinois, 2018-2019: U.S. Geological Survey data release, https://doi.org/10.5066/P9PBDSA1<br>\n<br>\nMcCafferty, A.E., and Brown, P.J., 2020, Airborne magnetic and radiometric survey, southeastern Illinois, western Kentucky, and southern Indiana, 2019: U.S. Geological Survey data release, https://doi.org/10.5066/P9R05B0M",
#   "browseCategories": [
#     "Data"
#   ],
#   "browseTypes": [
#     "Raster",
#     "GeoTIFF",
#     "Downloadable",
#     "Map Service",
#     "OGC WMS Service",
#     "OGC WFS Layer",
#     "OGC WMS Layer"
#   ],
#   "citation": "McCafferty, A.E. and Connell, D.M., 2022, Airborne horizontal-magnetic gradient and radiometric survey over parts of southeast Missouri, southern Illinois and western Kentucky- The Gap survey, 2021: U.S. Geological Survey data release, https://doi.org/10.5066/P9TK8KMM.",
#   "contacts": [
#     {
#       "active": true,
#       "contactType": "person",
#       "email": "anne@usgs.gov",
#       "firstName": "Anne",
#       "jobTitle": "Research Geophysicist",
#       "lastName": "McCafferty",
#       "middleName": "E",
#       "name": "Anne E McCafferty",
#       "oldPartyId": 6653,
#       "onlineResource": "https://www.usgs.gov/staff-profiles/anne-e-mccafferty",
#       "orcId": "0000-0001-5574-9201",
#       "organization": {
#         "displayText": "Geology, Geophysics, and Geochemistry Science Center"
#       },
#       "personalTitle": "Ms.",
#       "primaryLocation": {
#         "building": "DFC Bldg 20",
#         "buildingCode": "KAC",
#         "faxPhone": "3032361425",
#         "mailAddress": {
#           "city": "Denver",
#           "country": "USA",
#           "line1": "Box 25046, Denver Federal Center, Mail Stop 964",
#           "mailStopCode": "964",
#           "state": "CO",
#           "zip": "80225-0046"
#         },
#         "name": "Anne E McCafferty/GD/USGS/DOI - Primary Location",
#         "officePhone": "3032361397",
#         "streetAddress": {
#           "city": "Lakewood",
#           "country": "US",
#           "line1": "W 6th Ave Kipling St",
#           "state": "CO",
#           "zip": "80225"
#         }
#       },
#       "type": "Point of Contact"
#     },
#     {
#       "active": true,
#       "contactType": "person",
#       "email": "anne@usgs.gov",
#       "firstName": "Anne",
#       "jobTitle": "Research Geophysicist",
#       "lastName": "McCafferty",
#       "middleName": "E",
#       "name": "Anne E McCafferty",
#       "oldPartyId": 6653,
#       "onlineResource": "https://www.usgs.gov/staff-profiles/anne-e-mccafferty",
#       "orcId": "0000-0001-5574-9201",
#       "organization": {
#         "displayText": "Geology, Geophysics, and Geochemistry Science Center"
#       },
#       "personalTitle": "Ms.",
#       "primaryLocation": {
#         "building": "DFC Bldg 20",
#         "buildingCode": "KAC",
#         "faxPhone": "3032361425",
#         "mailAddress": {
#           "city": "Denver",
#           "country": "USA",
#           "line1": "Box 25046, Denver Federal Center, Mail Stop 964",
#           "mailStopCode": "964",
#           "state": "CO",
#           "zip": "80225-0046"
#         },
#         "name": "Anne E McCafferty/GD/USGS/DOI - Primary Location",
#         "officePhone": "3032361397",
#         "streetAddress": {
#           "city": "Lakewood",
#           "country": "US",
#           "line1": "W 6th Ave Kipling St",
#           "state": "CO",
#           "zip": "80225"
#         }
#       },
#       "type": "Originator"
#     },
#     {
#       "active": true,
#       "contactType": "person",
#       "email": "dconnell@usgs.gov",
#       "firstName": "Dylan",
#       "jobTitle": "Geophysicist",
#       "lastName": "Connell",
#       "middleName": "M",
#       "name": "Dylan M Connell",
#       "onlineResource": "https://www.usgs.gov/staff-profiles/dylan-connell",
#       "organization": {
#         "displayText": "Geology, Geophysics, and Geochemistry Science Center"
#       },
#       "primaryLocation": {
#         "buildingCode": "KAC",
#         "faxPhone": "3032361425",
#         "mailAddress": {
#           "city": "Denver",
#           "country": "USA",
#           "line1": "Box 25046, Denver Federal Center, Mail Stop 964",
#           "mailStopCode": "964",
#           "state": "CO",
#           "zip": "80225-0046"
#         },
#         "name": "Dylan Connell/GD/USGS/DOI - Primary Location",
#         "streetAddress": {
#           "city": "Lakewood",
#           "country": "US",
#           "line1": "W 6th Ave Kipling St",
#           "state": "CO",
#           "zip": "80225"
#         }
#       },
#       "type": "Metadata Contact"
#     },
#     {
#       "active": true,
#       "aliases": [
#         "{\"name\":\"Geological Survey (U.S.)\"}",
#         "{\"name\":\"USGS\"}",
#         "{\"name\":\"U.S. GEOLOGICAL SURVEY\"}"
#       ],
#       "contactType": "organization",
#       "fbmsCodes": [
#         "GG00000000"
#       ],
#       "logoUrl": "http://my.usgs.gov/static-cache/images/dataOwner/v1/logosMed/USGSLogo.gif",
#       "name": "U.S. Geological Survey",
#       "oldPartyId": 18139,
#       "onlineResource": "http://www.usgs.gov/",
#       "organization": {},
#       "primaryLocation": {
#         "mailAddress": {},
#         "name": "U.S. Geological Survey - Location",
#         "streetAddress": {}
#       },
#       "smallLogoUrl": "http://my.usgs.gov/static-cache/images/dataOwner/v1/logosSmall/USGSLogo.gif",
#       "type": "Publisher"
#     },
#     {
#       "contactType": "organization",
#       "email": "sciencebase@usgs.gov",
#       "name": "U.S. Geological Survey - ScienceBase",
#       "oldPartyId": 70157,
#       "onlineResource": "https://www.sciencebase.gov",
#       "organization": {},
#       "primaryLocation": {
#         "mailAddress": {
#           "city": "Denver",
#           "country": "United States",
#           "line1": "Denver Federal Center",
#           "line2": "Building 810",
#           "mailStopCode": "302",
#           "state": "CO",
#           "zip": "80225"
#         },
#         "name": "U.S. Geological Survey - ScienceBase - Location",
#         "officePhone": "18882758747",
#         "streetAddress": {}
#       },
#       "type": "Distributor"
#     },
#     {
#       "active": true,
#       "contactType": "organization",
#       "name": "Geology, Geophysics, and Geochemistry Science Center",
#       "oldPartyId": 17386,
#       "organization": {},
#       "primaryLocation": {
#         "mailAddress": {},
#         "name": "Denver Federal Center - DFC Bldg 20 [KAC]",
#         "streetAddress": {}
#       },
#       "type": "SDC Data Owner"
#     },
#     {
#       "contactType": "organization",
#       "name": "Energy and Minerals",
#       "organization": {
#         "directoryId": "64232",
#         "displayText": "Energy and Minerals"
#       },
#       "primaryLocation": {
#         "mailAddress": {},
#         "streetAddress": {}
#       },
#       "type": "USGS Mission Area"
#     }
#   ],
#   "dates": [
#     {
#       "dateString": "2022-04-04",
#       "label": "Publication Date",
#       "type": "Publication"
#     },
#     {
#       "dateString": "2020-03-02",
#       "label": "",
#       "type": "Start"
#     },
#     {
#       "dateString": "2021-04-20",
#       "label": "",
#       "type": "End"
#     }
#   ],
#   "distributionLinks": [
#     {
#       "files": "",
#       "name": "",
#       "rel": "alternate",
#       "title": "KML Service",
#       "type": "kml",
#       "typeLabel": "KML Download",
#       "uri": "https://www.sciencebase.gov/catalogMaps/mapping/ows/62434c50d34e22d73748d366?mode=download&request=kml&service=wms&layers=Gap_TF3ANM"
#     },
#     {
#       "files": "",
#       "name": "",
#       "rel": "alternate",
#       "title": "ScienceBase WMS Service",
#       "type": "serviceCapabilitiesUrl",
#       "typeLabel": "OGC Service Capabilities URL",
#       "uri": "https://www.sciencebase.gov/catalogMaps/mapping/ows/62434c50d34e22d73748d366?service=wms&request=getcapabilities&version=1.3.0"
#     },
#     {
#       "files": "",
#       "name": "",
#       "rel": "alternate",
#       "title": "ScienceBase WCS Service",
#       "type": "serviceCapabilitiesUrl",
#       "typeLabel": "OGC Service Capabilities URL",
#       "uri": "https://www.sciencebase.gov/catalogMaps/mapping/ows/62434c50d34e22d73748d366?service=wcs&request=getcapabilities&version=1.0.0"
#     },
#     {
#       "files": [
#         {
#           "contentType": "text/plain",
#           "name": "Gap_TF3ANM/Gap_TF3ANM.tfw",
#           "size": 92,
#           "title": "GeoTiff of Gap survey total magnetic intensity in nT"
#         },
#         {
#           "contentType": "image/geotiff",
#           "name": "Gap_TF3ANM/Gap_TF3ANM.tif",
#           "size": 26226736,
#           "title": "GeoTiff of Gap survey total magnetic intensity in nT"
#         },
#         {
#           "contentType": "application/sld+xml",
#           "name": "Gap_TF3ANM/Gap_TF3ANM.tif-ColorRamp.SLD",
#           "size": 2143,
#           "title": null
#         },
#         {
#           "contentType": "image/jpeg",
#           "name": "TotalMagneticIntensity.jpg",
#           "size": 2955928,
#           "title": "Total magnetic intensity anomaly"
#         },
#         {
#           "contentType": "application/json",
#           "name": "MO20F0196_GAP_DataDictionary_MAG_data.json",
#           "size": 11400,
#           "title": "Data Dictionary for magnetic flight line data"
#         },
#         {
#           "contentType": "text/csv",
#           "name": "MO20F0196_USGS_GAP_MagneticFlightLineData.csv",
#           "size": 5501234955,
#           "title": "Tabular Magnetic Flight Line Data"
#         },
#         {
#           "contentType": "application/fgdc+xml",
#           "name": "MO20F0196_GAP_MagChild_FGDCmetadata.xml",
#           "size": 36044,
#           "title": ""
#         }
#       ],
#       "name": "Airbornemagneti.zip",
#       "rel": "alternate",
#       "title": "Download Attached Files",
#       "type": "downloadLink",
#       "typeLabel": "Download Link",
#       "uri": "https://www.sciencebase.gov/catalog/file/get/62434c50d34e22d73748d366"
#     }
#   ],
#   "extents": [
#     3477307
#   ],
#   "facets": [
#     {
#       "boundingBox": {
#         "maxX": -88.83873304445018,
#         "maxY": 38.29469526769931,
#         "minX": -90.0094544122753,
#         "minY": 36.83084048395399
#       },
#       "className": "gov.sciencebase.catalog.item.facet.RasterFacet",
#       "facetName": "Raster",
#       "files": [
#         {
#           "bucket": null,
#           "checksum": null,
#           "contentEncoding": null,
#           "contentType": "text/plain",
#           "cuid": null,
#           "dateUploaded": "2022-06-29T16:22:42Z",
#           "downloadUri": "https://www.sciencebase.gov/catalog/file/get/62434c50d34e22d73748d366?f=__disk__ab%2F63%2Fd3%2Fab63d3d78ee5dc5c9dc7552d6d4fdbbaca9fb9a2",
#           "imageHeight": null,
#           "imageWidth": null,
#           "key": null,
#           "movedToS3": null,
#           "name": "Gap_TF3ANM.tfw",
#           "node": null,
#           "originalMetadata": null,
#           "pathOnDisk": "__disk__ab/63/d3/ab63d3d78ee5dc5c9dc7552d6d4fdbbaca9fb9a2",
#           "processToken": null,
#           "processed": null,
#           "published": null,
#           "s3Object": null,
#           "size": 92,
#           "title": "GeoTiff of Gap survey total magnetic intensity in nT",
#           "uploadedBy": "dconnell@usgs.gov",
#           "url": "https://www.sciencebase.gov/catalog/file/get/62434c50d34e22d73748d366?f=__disk__ab%2F63%2Fd3%2Fab63d3d78ee5dc5c9dc7552d6d4fdbbaca9fb9a2",
#           "useForPreview": null,
#           "viewUri": "https://www.sciencebase.gov/catalog/file/get/62434c50d34e22d73748d366?f=__disk__ab%2F63%2Fd3%2Fab63d3d78ee5dc5c9dc7552d6d4fdbbaca9fb9a2&allowOpen=true"
#         },
#         {
#           "bucket": null,
#           "checksum": null,
#           "contentEncoding": null,
#           "contentType": "image/geotiff",
#           "cuid": null,
#           "dateUploaded": "2022-06-29T16:22:42Z",
#           "downloadUri": "https://www.sciencebase.gov/catalog/file/get/62434c50d34e22d73748d366?f=__disk__57%2F65%2F2e%2F57652e68c8836f99238ee8788a1d5087ab918bdc",
#           "imageHeight": null,
#           "imageWidth": null,
#           "key": null,
#           "movedToS3": null,
#           "name": "Gap_TF3ANM.tif",
#           "node": null,
#           "originalMetadata": null,
#           "pathOnDisk": "__disk__57/65/2e/57652e68c8836f99238ee8788a1d5087ab918bdc",
#           "processToken": null,
#           "processed": null,
#           "published": null,
#           "s3Object": null,
#           "size": 26226736,
#           "title": "GeoTiff of Gap survey total magnetic intensity in nT",
#           "uploadedBy": "dconnell@usgs.gov",
#           "url": "https://www.sciencebase.gov/catalog/file/get/62434c50d34e22d73748d366?f=__disk__57%2F65%2F2e%2F57652e68c8836f99238ee8788a1d5087ab918bdc",
#           "useForPreview": null
#         },
#         {
#           "bucket": null,
#           "checksum": null,
#           "contentEncoding": null,
#           "contentType": "application/sld+xml",
#           "cuid": null,
#           "dateUploaded": "2022-06-29T16:25:21Z",
#           "downloadUri": "https://www.sciencebase.gov/catalog/file/get/62434c50d34e22d73748d366?f=__disk__53%2F80%2F30%2F538030c130851803563b81579353eed272095811",
#           "imageHeight": null,
#           "imageWidth": null,
#           "key": null,
#           "movedToS3": false,
#           "name": "Gap_TF3ANM.tif-ColorRamp.SLD",
#           "node": null,
#           "originalMetadata": false,
#           "pathOnDisk": "__disk__53/80/30/538030c130851803563b81579353eed272095811",
#           "processToken": null,
#           "processed": false,
#           "published": false,
#           "s3Object": null,
#           "size": 2143,
#           "title": null,
#           "uploadedBy": "dconnell@usgs.gov",
#           "url": "https://www.sciencebase.gov/catalog/file/get/62434c50d34e22d73748d366?f=__disk__53%2F80%2F30%2F538030c130851803563b81579353eed272095811",
#           "useForPreview": false
#         }
#       ],
#       "name": "Gap_TF3ANM",
#       "nativeCrs": "EPSG:32616",
#       "rasterType": "GeoTIFF"
#     }
#   ],
#   "files": [
#     {
#       "bucket": null,
#       "checksum": {
#         "type": "MD5",
#         "value": "5cb3f957a19b88ef507c600424f1ae00"
#       },
#       "contentEncoding": null,
#       "contentType": "image/jpeg",
#       "cuid": null,
#       "dateUploaded": "2022-03-29T21:31:34Z",
#       "downloadUri": "https://www.sciencebase.gov/catalog/file/get/62434c50d34e22d73748d366?f=__disk__20%2Fc9%2F37%2F20c93713022bcbe655c26bbac2ccca0dd3f3221a",
#       "imageHeight": 2411,
#       "imageWidth": 1765,
#       "key": null,
#       "movedToS3": null,
#       "name": "TotalMagneticIntensity.jpg",
#       "node": null,
#       "originalMetadata": false,
#       "pathOnDisk": "__disk__20/c9/37/20c93713022bcbe655c26bbac2ccca0dd3f3221a",
#       "previewImage": {
#         "large": {
#           "height": 750,
#           "uri": "https://www.sciencebase.gov/catalog/file/get/62434c50d34e22d73748d366?f=__disk__20%2Fc9%2F37%2F20c93713022bcbe655c26bbac2ccca0dd3f3221a&width=549&height=750",
#           "width": 549
#         },
#         "medium": {
#           "height": 435,
#           "uri": "https://www.sciencebase.gov/catalog/file/get/62434c50d34e22d73748d366?f=__disk__20%2Fc9%2F37%2F20c93713022bcbe655c26bbac2ccca0dd3f3221a&width=318&height=435",
#           "width": 318
#         },
#         "small": {
#           "height": 263,
#           "uri": "https://www.sciencebase.gov/catalog/file/get/62434c50d34e22d73748d366?f=__disk__20%2Fc9%2F37%2F20c93713022bcbe655c26bbac2ccca0dd3f3221a&width=193&height=263",
#           "width": 193
#         },
#         "thumbnail": {
#           "height": 113,
#           "uri": "https://www.sciencebase.gov/catalog/file/get/62434c50d34e22d73748d366?f=__disk__20%2Fc9%2F37%2F20c93713022bcbe655c26bbac2ccca0dd3f3221a&width=83&height=113",
#           "width": 83
#         }
#       },
#       "processToken": null,
#       "processed": false,
#       "published": null,
#       "s3Object": null,
#       "size": 2955928,
#       "title": "Total magnetic intensity anomaly",
#       "uploadedBy": "anne@usgs.gov",
#       "url": "https://www.sciencebase.gov/catalog/file/get/62434c50d34e22d73748d366?f=__disk__20%2Fc9%2F37%2F20c93713022bcbe655c26bbac2ccca0dd3f3221a",
#       "useForPreview": false,
#       "viewUri": "https://www.sciencebase.gov/catalog/file/get/62434c50d34e22d73748d366?f=__disk__20%2Fc9%2F37%2F20c93713022bcbe655c26bbac2ccca0dd3f3221a&width=1765&height=2411"
#     },
#     {
#       "bucket": null,
#       "checksum": {
#         "type": "MD5",
#         "value": "27ae62b0d2b04d68c3cbf2014d12d658"
#       },
#       "contentEncoding": null,
#       "contentType": "application/json",
#       "cuid": null,
#       "dateUploaded": "2022-04-05T20:32:00Z",
#       "downloadUri": "https://www.sciencebase.gov/catalog/file/get/62434c50d34e22d73748d366?f=__disk__8a%2F26%2F1d%2F8a261da27023e9bb6b0e2096870ca02e7f8cf504",
#       "imageHeight": null,
#       "imageWidth": null,
#       "key": null,
#       "movedToS3": null,
#       "name": "MO20F0196_GAP_DataDictionary_MAG_data.json",
#       "node": null,
#       "originalMetadata": false,
#       "pathOnDisk": "__disk__8a/26/1d/8a261da27023e9bb6b0e2096870ca02e7f8cf504",
#       "processToken": null,
#       "processed": false,
#       "published": null,
#       "s3Object": null,
#       "size": 11400,
#       "title": "Data Dictionary for magnetic flight line data",
#       "uploadedBy": "dconnell@usgs.gov",
#       "url": "https://www.sciencebase.gov/catalog/file/get/62434c50d34e22d73748d366?f=__disk__8a%2F26%2F1d%2F8a261da27023e9bb6b0e2096870ca02e7f8cf504",
#       "useForPreview": false
#     },
#     {
#       "bucket": null,
#       "checksum": null,
#       "contentEncoding": null,
#       "contentType": "text/csv",
#       "cuid": null,
#       "dateUploaded": "2022-05-17T20:18:45Z",
#       "downloadUri": "https://www.sciencebase.gov/catalog/file/get/62434c50d34e22d73748d366?f=__disk__68%2F98%2Fdb%2F6898db1da809a774f7ed36d4d7a82a6afd517465",
#       "imageHeight": null,
#       "imageWidth": null,
#       "key": null,
#       "movedToS3": null,
#       "name": "MO20F0196_USGS_GAP_MagneticFlightLineData.csv",
#       "node": null,
#       "originalMetadata": null,
#       "pathOnDisk": "__disk__68/98/db/6898db1da809a774f7ed36d4d7a82a6afd517465",
#       "processToken": null,
#       "processed": null,
#       "published": null,
#       "s3DownloadRequestPageUri": "https://www.sciencebase.gov/catalog/item/requestDownload/62434c50d34e22d73748d366?filePath=__disk__68%2F98%2Fdb%2F6898db1da809a774f7ed36d4d7a82a6afd517465",
#       "s3Object": {
#         "bucket": "prod-is-s3-service",
#         "contentType": "text/csv",
#         "dateUploaded": "2022-06-17T18:10:42Z",
#         "filePath": "62434c50d34e22d73748d366/6898db1da809a774f7ed36d4d7a82a6afd517465/MO20F0196_USGS_GAP_MagneticFlightLineData.csv",
#         "name": "MO20F0196_USGS_GAP_MagneticFlightLineData.csv",
#         "s3Source": null,
#         "s3SourceBucket": null,
#         "s3SourcePath": null,
#         "size": 5501234955,
#         "status": "Complete",
#         "title": "S3 bucket copy of file MO20F0196_USGS_GAP_MagneticFlightLineData.csv",
#         "uploadedBy": "pbrown@usgs.gov"
#       },
#       "size": 5501234955,
#       "title": "Tabular Magnetic Flight Line Data",
#       "uploadedBy": "jsheflin@contractor.usgs.gov",
#       "url": "https://www.sciencebase.gov/catalog/file/get/62434c50d34e22d73748d366?f=__disk__68%2F98%2Fdb%2F6898db1da809a774f7ed36d4d7a82a6afd517465",
#       "useForPreview": null
#     },
#     {
#       "bucket": null,
#       "checksum": {
#         "type": "MD5",
#         "value": "352b4d1769879475c52aae68ecf65f61"
#       },
#       "contentEncoding": null,
#       "contentType": "application/fgdc+xml",
#       "cuid": null,
#       "dateUploaded": "2022-06-29T20:10:33Z",
#       "downloadUri": "https://www.sciencebase.gov/catalog/file/get/62434c50d34e22d73748d366?f=__disk__c7%2F5f%2F54%2Fc75f5490903fba720a3e53c7c96becec9ed0a603",
#       "imageHeight": null,
#       "imageWidth": null,
#       "key": null,
#       "metadataHtmlViewUri": "https://www.sciencebase.gov/catalog/file/get/62434c50d34e22d73748d366?f=__disk__c7%2F5f%2F54%2Fc75f5490903fba720a3e53c7c96becec9ed0a603&transform=1",
#       "movedToS3": null,
#       "name": "MO20F0196_GAP_MagChild_FGDCmetadata.xml",
#       "node": null,
#       "originalMetadata": true,
#       "pathOnDisk": "__disk__c7/5f/54/c75f5490903fba720a3e53c7c96becec9ed0a603",
#       "processToken": null,
#       "processed": false,
#       "published": null,
#       "s3Object": null,
#       "size": 36044,
#       "title": "",
#       "uploadedBy": "dconnell@usgs.gov",
#       "url": "https://www.sciencebase.gov/catalog/file/get/62434c50d34e22d73748d366?f=__disk__c7%2F5f%2F54%2Fc75f5490903fba720a3e53c7c96becec9ed0a603",
#       "useForPreview": false
#     }
#   ],
#   "hasChildren": false,
#   "id": "62434c50d34e22d73748d366",
#   "link": {
#     "rel": "self",
#     "url": "https://www.sciencebase.gov/catalog/item/62434c50d34e22d73748d366"
#   },
#   "locked": false,
#   "maintenanceUpdateFrequency": "None planned",
#   "parentId": "624347bfd34e22d73748d357",
#   "permissions": {
#     "read": {
#       "acl": [
#         "USER:anne@usgs.gov",
#         "ROLE:BAO",
#         "USER:abern@usgs.gov",
#         "USER:cmoses@usgs.gov",
#         "ROLE:CGGSC_CMERSC_Data_Managers",
#         "USER:pbedrosian@usgs.gov"
#       ],
#       "inherited": true,
#       "inheritsFromId": "624347bfd34e22d73748d357"
#     },
#     "write": {
#       "acl": [
#         "ROLE:CGGSC_CMERSC_Data_Managers",
#         "ROLE:ScienceBase_Data_Release_Team",
#         "USER:anne@usgs.gov",
#         "USER:dconnell@usgs.gov",
#         "USER:pbrown@usgs.gov"
#       ],
#       "inherited": true,
#       "inheritsFromId": "624347bfd34e22d73748d357"
#     }
#   },
#   "previewImage": {
#     "alternateImages": [
#       {
#         "from": "mapPreview",
#         "original": {
#           "height": 240,
#           "size": 165528,
#           "uri": "https://www.sciencebase.gov/catalog/file/get/62434c50d34e22d73748d366?f=__disk__66%2F48%2F60%2F6648601c220bc6b45483777a72061a933ca49f50",
#           "viewUri": "https://www.sciencebase.gov/catalog/file/get/62434c50d34e22d73748d366?f=__disk__66%2F48%2F60%2F6648601c220bc6b45483777a72061a933ca49f50&width=360&height=240",
#           "viewUrl": "https://www.sciencebase.gov/catalog/file/get/62434c50d34e22d73748d366?deprecated=__use__viewUri__instead__&f=__disk__66%2F48%2F60%2F6648601c220bc6b45483777a72061a933ca49f50&width=360&height=240",
#           "width": 360
#         },
#         "thumbnail": {
#           "height": 100,
#           "uri": "https://www.sciencebase.gov/catalog/file/get/62434c50d34e22d73748d366?f=__disk__66%2F48%2F60%2F6648601c220bc6b45483777a72061a933ca49f50&width=150&height=100",
#           "width": 150
#         }
#       }
#     ],
#     "from": "attachedFile",
#     "large": {
#       "height": 750,
#       "uri": "https://www.sciencebase.gov/catalog/file/get/62434c50d34e22d73748d366?f=__disk__20%2Fc9%2F37%2F20c93713022bcbe655c26bbac2ccca0dd3f3221a&width=549&height=750",
#       "width": 549
#     },
#     "medium": {
#       "height": 435,
#       "uri": "https://www.sciencebase.gov/catalog/file/get/62434c50d34e22d73748d366?f=__disk__20%2Fc9%2F37%2F20c93713022bcbe655c26bbac2ccca0dd3f3221a&width=318&height=435",
#       "width": 318
#     },
#     "original": {
#       "height": 2411,
#       "size": 2955928,
#       "title": "Total magnetic intensity anomaly",
#       "uri": "https://www.sciencebase.gov/catalog/file/get/62434c50d34e22d73748d366?f=__disk__20%2Fc9%2F37%2F20c93713022bcbe655c26bbac2ccca0dd3f3221a",
#       "viewUri": "https://www.sciencebase.gov/catalog/file/get/62434c50d34e22d73748d366?f=__disk__20%2Fc9%2F37%2F20c93713022bcbe655c26bbac2ccca0dd3f3221a&width=1765&height=2411",
#       "viewUrl": "https://www.sciencebase.gov/catalog/file/get/62434c50d34e22d73748d366?deprecated=__use__viewUri__instead__&f=__disk__20%2Fc9%2F37%2F20c93713022bcbe655c26bbac2ccca0dd3f3221a&width=1765&height=2411",
#       "width": 1765
#     },
#     "small": {
#       "height": 263,
#       "uri": "https://www.sciencebase.gov/catalog/file/get/62434c50d34e22d73748d366?f=__disk__20%2Fc9%2F37%2F20c93713022bcbe655c26bbac2ccca0dd3f3221a&width=193&height=263",
#       "width": 193
#     },
#     "thumbnail": {
#       "height": 113,
#       "uri": "https://www.sciencebase.gov/catalog/file/get/62434c50d34e22d73748d366?f=__disk__20%2Fc9%2F37%2F20c93713022bcbe655c26bbac2ccca0dd3f3221a&width=83&height=113",
#       "width": 83
#     }
#   },
#   "provenance": {
#     "createdBy": "anne@usgs.gov",
#     "dataSource": "Input directly",
#     "dateCreated": "2022-03-29T18:13:36Z",
#     "lastUpdated": "2022-06-29T20:10:37Z",
#     "lastUpdatedBy": "dconnell@usgs.gov"
#   },
#   "purpose": "The airborne magnetic and radiometric survey was designed to augment and connect several previous USGS geophysical surveys in order to provide a continuous representation of the magnetic and radiometric fields from southeast Missouri to western Kentucky. These data will be used to better understand the surface and concealed geologic framework.",
#   "relatedItems": {
#     "link": {
#       "rel": "related",
#       "url": "https://www.sciencebase.gov/catalog/itemLinks?itemId=62434c50d34e22d73748d366"
#     }
#   },
#   "spatial": {
#     "boundingBox": {
#       "maxX": -88.83967198,
#       "maxY": 38.29528422,
#       "minX": -89.95097716,
#       "minY": 36.83041509
#     },
#     "representationalPoint": [
#       -89.39410000000001,
#       37.5612
#     ],
#     "representationalPointIsDerived": true
#   },
#   "summary": "Airborne magnetic gradiometry data along the tie and flight lines are provided here in CSV (Comma Separated Value) format along with a GeoTIFF grid of the total magnetic intensity (TMI) in nanoTeslas.  Along with the data provided on this child page, a report in PDF format by the airborne contractor that describes the technical details of the data collection, reduction and processing procedures and a zip file that contains the contractor's deliverable products (Geosoft databases and grids) for the magnetic and radiometric survey is available on the parent page (https://doi.org/10.5066/P9TK8KMM).  References Cited:  McCafferty, A.E., and Johnson, M.R., 2019, Airborne magnetic and radiometric survey, southeast Missouri and western Illinois, [...]",
#   "systemTypes": [
#     "Downloadable",
#     "Mappable"
#   ],
#   "tags": [
#     {
#       "name": "USGS Science Data Catalog (SDC)",
#       "type": "Harvest Set"
#     },
#     {
#       "name": "geophysics",
#       "scheme": "USGS Thesaurus",
#       "type": "Theme"
#     },
#     {
#       "name": "geospatial datasets",
#       "scheme": "USGS Thesaurus",
#       "type": "Theme"
#     },
#     {
#       "name": "aeromagnetic surveying",
#       "scheme": "USGS Thesaurus",
#       "type": "Theme"
#     },
#     {
#       "name": "aeroradiometric surveying",
#       "scheme": "USGS Thesaurus",
#       "type": "Theme"
#     },
#     {
#       "name": "potassium",
#       "scheme": "USGS Thesaurus",
#       "type": "Theme"
#     },
#     {
#       "name": "uranium",
#       "scheme": "USGS Thesaurus",
#       "type": "Theme"
#     },
#     {
#       "name": "thorium",
#       "scheme": "USGS Thesaurus",
#       "type": "Theme"
#     },
#     {
#       "name": "Geology, Geophysics, and Geochemistry Science Center",
#       "scheme": "none",
#       "type": "Theme"
#     },
#     {
#       "name": "GGGSC",
#       "scheme": "none",
#       "type": "Theme"
#     },
#     {
#       "name": "Earthquake Hazards Program",
#       "scheme": "none",
#       "type": "Theme"
#     },
#     {
#       "name": "EHP",
#       "scheme": "none",
#       "type": "Theme"
#     },
#     {
#       "name": "National Cooperative Geologic Mapping Program",
#       "scheme": "none",
#       "type": "Theme"
#     },
#     {
#       "name": "NCGMP",
#       "scheme": "none",
#       "type": "Theme"
#     },
#     {
#       "name": "Mineral Resources Program",
#       "scheme": "none",
#       "type": "Theme"
#     },
#     {
#       "name": "MRP",
#       "scheme": "none",
#       "type": "Theme"
#     },
#     {
#       "name": "Earth Mapping Resources Initiative",
#       "scheme": "none",
#       "type": "Theme"
#     },
#     {
#       "name": "EarthMRI",
#       "scheme": "none",
#       "type": "Theme"
#     },
#     {
#       "name": "U.S. Geological Survey",
#       "scheme": "none",
#       "type": "Theme"
#     },
#     {
#       "name": "USGS",
#       "scheme": "none",
#       "type": "Theme"
#     },
#     {
#       "name": "airborne geophysical survey",
#       "scheme": "none",
#       "type": "Theme"
#     },
#     {
#       "name": "horizontal magnetic gradiometry",
#       "scheme": "none",
#       "type": "Theme"
#     },
#     {
#       "name": "geoscientificInformation",
#       "scheme": "ISO 19115 Topic Category",
#       "type": "Theme"
#     },
#     {
#       "name": "economy",
#       "scheme": "ISO 19115 Topic Category",
#       "type": "Theme"
#     },
#     {
#       "name": "United States",
#       "scheme": "Common geographic areas",
#       "type": "Place"
#     },
#     {
#       "name": "Economic Geology",
#       "type": "USGS Scientific Topic Keyword"
#     },
#     {
#       "name": "Geophysics",
#       "type": "USGS Scientific Topic Keyword"
#     },
#     {
#       "name": "Mineral Resources",
#       "type": "USGS Scientific Topic Keyword"
#     },
#     {
#       "name": "Sedimentology",
#       "type": "USGS Scientific Topic Keyword"
#     },
#     {
#       "name": "Seismology",
#       "type": "USGS Scientific Topic Keyword"
#     },
#     {
#       "name": "Structural Geology",
#       "type": "USGS Scientific Topic Keyword"
#     },
#     {
#       "name": "Cape Girardeau",
#       "scheme": "Geographic Names Information System (GNIS)",
#       "type": "Place"
#     },
#     {
#       "name": "Ballard County",
#       "scheme": "Geographic Names Information System (GNIS)",
#       "type": "Place"
#     },
#     {
#       "name": "Carlisle County",
#       "scheme": "Geographic Names Information System (GNIS)",
#       "type": "Place"
#     },
#     {
#       "name": "Jackson County",
#       "scheme": "Geographic Names Information System (GNIS)",
#       "type": "Place"
#     },
#     {
#       "name": "Jefferson County",
#       "scheme": "Geographic Names Information System (GNIS)",
#       "type": "Place"
#     },
#     {
#       "name": "Johnson County",
#       "scheme": "Geographic Names Information System (GNIS)",
#       "type": "Place"
#     },
#     {
#       "name": "Massac County",
#       "scheme": "Geographic Names Information System (GNIS)",
#       "type": "Place"
#     },
#     {
#       "name": "Alexander County",
#       "scheme": "Geographic Names Information System (GNIS)",
#       "type": "Place"
#     },
#     {
#       "name": "McCracken County",
#       "scheme": "Geographic Names Information System (GNIS)",
#       "type": "Place"
#     },
#     {
#       "name": "Perry County",
#       "scheme": "Geographic Names Information System (GNIS)",
#       "type": "Place"
#     },
#     {
#       "name": "Pulaski County",
#       "scheme": "Geographic Names Information System (GNIS)",
#       "type": "Place"
#     },
#     {
#       "name": "Randolph County",
#       "scheme": "Geographic Names Information System (GNIS)",
#       "type": "Place"
#     },
#     {
#       "name": "St. Clair County",
#       "scheme": "Geographic Names Information System (GNIS)",
#       "type": "Place"
#     },
#     {
#       "name": "Union County",
#       "scheme": "Geographic Names Information System (GNIS)",
#       "type": "Place"
#     },
#     {
#       "name": "Washington County",
#       "scheme": "Geographic Names Information System (GNIS)",
#       "type": "Place"
#     },
#     {
#       "name": "Williamson County",
#       "scheme": "Geographic Names Information System (GNIS)",
#       "type": "Place"
#     },
#     {
#       "name": "Franklin County",
#       "scheme": "Geographic Names Information System (GNIS)",
#       "type": "Place"
#     },
#     {
#       "name": "Bollinger County",
#       "scheme": "Geographic Names Information System (GNIS)",
#       "type": "Place"
#     },
#     {
#       "name": "Cape Girardeau County",
#       "scheme": "Geographic Names Information System (GNIS)",
#       "type": "Place"
#     },
#     {
#       "name": "Mississippi County",
#       "scheme": "Geographic Names Information System (GNIS)",
#       "type": "Place"
#     },
#     {
#       "name": "New Madrid County",
#       "scheme": "Geographic Names Information System (GNIS)",
#       "type": "Place"
#     },
#     {
#       "name": "Perry County",
#       "scheme": "Geographic Names Information System (GNIS)",
#       "type": "Place"
#     },
#     {
#       "name": "Scott County",
#       "scheme": "Geographic Names Information System (GNIS)",
#       "type": "Place"
#     },
#     {
#       "name": "Stoddard County",
#       "scheme": "Geographic Names Information System (GNIS)",
#       "type": "Place"
#     },
#     {
#       "name": "Missouri",
#       "scheme": "Geographic Names Information System (GNIS)",
#       "type": "Place"
#     },
#     {
#       "name": "Illinois",
#       "scheme": "Geographic Names Information System (GNIS)",
#       "type": "Place"
#     },
#     {
#       "name": "Kentucky",
#       "scheme": "Geographic Names Information System (GNIS)",
#       "type": "Place"
#     }
#   ],
#   "title": "Airborne magnetic flight line data over parts of southeast Missouri, southern Illinois and western Kentucky- The Gap survey, 2021",
#   "webLinks": [
#     {
#       "hidden": false,
#       "rel": "related",
#       "type": "Online Link",
#       "uri": "https://doi.org/10.5066/P9TK8KMM"
#     },
#     {
#       "hidden": false,
#       "length": 1719664640,
#       "rel": "related",
#       "title": "ZIP",
#       "type": "webLink",
#       "uri": "https://doi.org/10.5066/P9TK8KMM"
#     },
#     {
#       "hidden": false,
#       "length": 2956984,
#       "rel": "related",
#       "title": "GeoTIFF",
#       "type": "webLink",
#       "uri": "https://doi.org/10.5066/P9TK8KMM"
#     },
#     {
#       "hidden": false,
#       "length": 2956984,
#       "rel": "related",
#       "title": "GeoTIFF",
#       "type": "catalogItemUrl",
#       "uri": "https://www.sciencebase.gov/catalog/item/62434c50d34e22d73748d366"
#     }
#   ]
# }

# %%
# Check other citation information:
for theme in root.iter('citeinfo'):
 othercit = theme.find('othercit')
 printmd ("**Other Citation Text:**\n\n" + othercit.text)
# Out:
# **Other Citation Text:**
#
# Additional information about Originators: Ann E. McCafferty, https://orcid.org/0000-0001-5574-9201; Dylan M. Connell, https://orcid.org/0000-0001-8678-2776.  Suggested Citation: McCafferty, A.E. and Connell, D.M., 2022, Airborne horizontal-magnetic gradient and radiometric survey over parts of southeast Missouri, southern Illinois and western Kentucky- The Gap survey, 2021: U.S. Geological Survey data release, https://doi.org/10.5066/P9TK8KMM.
# **Other Citation Text:**
#
# Day, W.D., 2019, The Earth MappingResources Initiative (Earth MRI): Mapping the nations critical mineral resources: U.S. Geological Survey Fact Sheet 2019-3007, https://pubs.usgs.gov/fs/2019/3007/fs20193007.pdf.

# %% [markdown]
# - No recommended changes to citations

# %%
#Get the names of the file items in ScienceBase:
#print(item_json['files'])
# Create Arrays of process information
jpg_files = []
jpg_url = []
jpg_size = []

for item in item_json['files']:
    print (item['name'],', ', item['url'], ', ', item['size'])
    jpg_files.append(item['name'])
    jpg_url.append(item['url'])
    jpg_size.append(int(item['size']))
# Out:
# TotalMagneticIntensity.jpg ,  https://www.sciencebase.gov/catalog/file/get/62434c50d34e22d73748d366?f=__disk__20%2Fc9%2F37%2F20c93713022bcbe655c26bbac2ccca0dd3f3221a ,  2955928
# MO20F0196_GAP_DataDictionary_MAG_data.json ,  https://www.sciencebase.gov/catalog/file/get/62434c50d34e22d73748d366?f=__disk__8a%2F26%2F1d%2F8a261da27023e9bb6b0e2096870ca02e7f8cf504 ,  11400
# MO20F0196_USGS_GAP_MagneticFlightLineData.csv ,  https://www.sciencebase.gov/catalog/file/get/62434c50d34e22d73748d366?f=__disk__68%2F98%2Fdb%2F6898db1da809a774f7ed36d4d7a82a6afd517465 ,  5501234955
# MO20F0196_GAP_MagChild_FGDCmetadata.xml ,  https://www.sciencebase.gov/catalog/file/get/62434c50d34e22d73748d366?f=__disk__c7%2F5f%2F54%2Fc75f5490903fba720a3e53c7c96becec9ed0a603 ,  36044

# %%
#Get the names of the file items in ScienceBase, interesting that the Geotiif extention doesn't show up
#- need to fix this for future reviews.
#print(item_json['files'])

for item in item_json['files']:
    print (item['name'])
# Out:
# TotalMagneticIntensity.jpg
# MO20F0196_GAP_DataDictionary_MAG_data.json
# MO20F0196_USGS_GAP_MagneticFlightLineData.csv
# MO20F0196_GAP_MagChild_FGDCmetadata.xml

# %%
# Compare this to the metadata Entity and Atribute item
printmd ('**DETAILED Entity and Attributes:**')
for enttyp in root.iter('enttyp'):
 enttypl = enttyp.find('enttypl')
 print (enttypl.text)
printmd ('**Overview Only:**') 
for overview in root.iter('overview'):
 eaover = overview.find('eaover')
 print (eaover.text)
 eadetcit = overview.find('eadetcit')
 print (eadetcit.text)
# Out:
# **DETAILED Entity and Attributes:**
# TotalMagneticIntensity.jpg
# Gap_TF3ANM.tif
# MO20F0196_USGS_GAP_MagneticFlightLineData.csv
# **Overview Only:**
# Survey report from Terraquest. This report describes the survey parameters, field operations, and quality control procedures used to produce the magnetic and radiometric data.
# https://doi.org/10.5066/P9TK8KMM

# %% [markdown]
# > - Please add the Entity File Names (e.g. MO20F0196_USGS_GAP_OrigContractorDeliverable.zip, MO20F0196_USGS_GAP-Geophysical_Airborne_Survey_Report.pdf) to the E&A Overview section.
# > - Please add overview for json file

# %% [markdown]
# ##### b.	Links to data, publications, and services exist (although links may change when final DOI is assigned);

# %%
#Find all links in metdata and print out to check
#Note that this terminates the string listing at the first space after http - this isn't the end of the link
#As a result there are generally too many characters printed in the link - select corect part of URL and check
#manually in the web browser
#Find all links in metdata and print out to check
import re
linkLoc = [m.start() for m in re.finditer('http', metaData)]
#print (linkLoc)
for i in range(len(linkLoc)):
 indexSpace = metaData.find(' ',linkLoc[i])
 print ('indexSpace = ' + str(indexSpace))
 linkURL = metaData[linkLoc[i]:indexSpace]
 print (linkURL +'\n')
# Out:
# indexSpace = 614
# https://orcid.org/0000-0001-5574-9201;
#
# indexSpace = 671
# https://orcid.org/0000-0001-8678-2776.
#
# indexSpace = 1077
# https://doi.org/10.5066/P9TK8KMM.</othercit>
# 				<onlink>https://doi.org/10.5066/P9TK8KMM</onlink>
# 				<lworkcit>
# 					<citeinfo>
# 						<origin>Day,
#
# indexSpace = 1077
# https://doi.org/10.5066/P9TK8KMM</onlink>
# 				<lworkcit>
# 					<citeinfo>
# 						<origin>Day,
#
# indexSpace = 2087
# https://pubs.usgs.gov/fs/2019/3007/fs20193007.pdf.</othercit>
# 						<onlink>https://pubs.usgs.gov/fs/2019/3007/fs20193007.pdf</onlink>
# 						<onlink>https://permanent.fdlp.gov/gpo117974/fs20193007.pdf</onlink>
# 						<onlink>https://www.usgs.gov/special-topics/earth-mri</onlink>
# 					</citeinfo>
# 				</lworkcit>
# 			</citeinfo>
# 		</citation>
# 		<descript>
# 			<abstract>Airborne
#
# indexSpace = 2087
# https://pubs.usgs.gov/fs/2019/3007/fs20193007.pdf</onlink>
# 						<onlink>https://permanent.fdlp.gov/gpo117974/fs20193007.pdf</onlink>
# 						<onlink>https://www.usgs.gov/special-topics/earth-mri</onlink>
# 					</citeinfo>
# 				</lworkcit>
# 			</citeinfo>
# 		</citation>
# 		<descript>
# 			<abstract>Airborne
#
# indexSpace = 2087
# https://permanent.fdlp.gov/gpo117974/fs20193007.pdf</onlink>
# 						<onlink>https://www.usgs.gov/special-topics/earth-mri</onlink>
# 					</citeinfo>
# 				</lworkcit>
# 			</citeinfo>
# 		</citation>
# 		<descript>
# 			<abstract>Airborne
#
# indexSpace = 2087
# https://www.usgs.gov/special-topics/earth-mri</onlink>
# 					</citeinfo>
# 				</lworkcit>
# 			</citeinfo>
# 		</citation>
# 		<descript>
# 			<abstract>Airborne
#
# indexSpace = 2681
# https://doi.org/10.5066/P9TK8KMM).
#
# indexSpace = 5394
# https://doi.org/10.3133/fs20193007.
#
# McCafferty,
#
# indexSpace = 5603
# https://doi.org/10.5066/P9PBDSA1.
#
# McCafferty,
#
# indexSpace = 5996
# https://doi.org/10.5066/P9R05B0M</supplinf>
# 		</descript>
# 		<timeperd>
# 			<timeinfo>
# 				<rngdates>
# 					<begdate>20200302</begdate>
# 					<enddate>20210420</enddate>
# 				</rngdates>
# 			</timeinfo>
# 			<current>ground
#
# indexSpace = 30519
# https://doi.org/10.5066/P9TK8KMM</eadetcit>
# 		</overview>
# 	</eainfo>
# 	<distinfo>
# 		<distrib>
# 			<cntinfo>
# 				<cntorgp>
# 					<cntorg>U.S.
#
# indexSpace = 31049
# https://www.sciencebase.gov/catalog/item/62434c50d34e22d73748d366</resdesc>
# 		<distliab>Unless
#
# indexSpace = 32562
# https://www.sciencebase.gov/catalog/file/get/62434c50d34e22d73748d366?f=__disk__68%2F98%2Fdb%2F6898db1da809a774f7ed36d4d7a82a6afd517465</networkr>
# 								<networkr>https://doi.org/10.5066/P9TK8KMM</networkr>
# 								<networkr>https://www.sciencebase.gov/catalog/item/62434c50d34e22d73748d366</networkr>
# 							</networka>
# 						</computer>
# 					</onlinopt>
# 				</digtopt>
# 			</digform>
# 			<digform>
# 				<digtinfo>
# 					<formname>JPG</formname>
# 					<formvern>1</formvern>
# 					<formspec>TotalMagneticIntensity.jpg</formspec>
# 					<formcont>Image
#
# indexSpace = 32562
# https://doi.org/10.5066/P9TK8KMM</networkr>
# 								<networkr>https://www.sciencebase.gov/catalog/item/62434c50d34e22d73748d366</networkr>
# 							</networka>
# 						</computer>
# 					</onlinopt>
# 				</digtopt>
# 			</digform>
# 			<digform>
# 				<digtinfo>
# 					<formname>JPG</formname>
# 					<formvern>1</formvern>
# 					<formspec>TotalMagneticIntensity.jpg</formspec>
# 					<formcont>Image
#
# indexSpace = 32562
# https://www.sciencebase.gov/catalog/item/62434c50d34e22d73748d366</networkr>
# 							</networka>
# 						</computer>
# 					</onlinopt>
# 				</digtopt>
# 			</digform>
# 			<digform>
# 				<digtinfo>
# 					<formname>JPG</formname>
# 					<formvern>1</formvern>
# 					<formspec>TotalMagneticIntensity.jpg</formspec>
# 					<formcont>Image
#
# indexSpace = 33155
# https://www.sciencebase.gov/catalog/file/get/62434c50d34e22d73748d366?f=__disk__20%2Fc9%2F37%2F20c93713022bcbe655c26bbac2ccca0dd3f3221a</networkr>
# 							</networka>
# 						</computer>
# 					</onlinopt>
# 				</digtopt>
# 			</digform>
# 			<digform>
# 				<digtinfo>
# 					<formname>GeoTIFF</formname>
# 					<formvern>1</formvern>
# 					<formspec>Gap_TF3ANM.tif</formspec>
# 					<formcont>
#
# indexSpace = 33840
# https://www.sciencebase.gov/catalog/file/get/62434c50d34e22d73748d366?f=__disk__ab%2F63%2Fd3%2Fab63d3d78ee5dc5c9dc7552d6d4fdbbaca9fb9a2</networkr>
# 							</networka>
# 						</computer>
# 					</onlinopt>
# 				</digtopt>
# 			</digform>
# 			<digform>
# 				<digtinfo>
# 					<formname>JSON</formname>
# 					<formvern>1</formvern>
# 					<formspec>MO20F0196_USGS_GAP_MagneticFlightLineData.json</formspec>
# 					<formcont>JSON
#
# indexSpace = 34502
# https://www.sciencebase.gov/catalog/file/get/62434c50d34e22d73748d366?f=__disk__20%2Fc9%2F37%2F20c93713022bcbe655c26bbac2ccca0dd3f3221a</networkr>
# 							</networka>
# 						</computer>
# 					</onlinopt>
# 				</digtopt>
# 			</digform>
# 			<fees>none</fees>
# 		</stdorder>
# 	</distinfo>
# 	<metainfo>
# 		<metd>20220526</metd>
# 		<metc>
# 			<cntinfo>
# 				<cntperp>
# 					<cntper>Dylan

# %% [markdown]
# > - **Be sure to check DOI links when SB item goes public**
# > - Got quite a bit other broken links - that's the problem with direct file URLs - they can change when the file is reuploaded or for other changes sometimes performed by ScienceBase
#
# Invalid Network_Resource_Name: "https://www.sciencebase.gov/catalog/file/get/62434c50d34e22d73748d366?f=__disk__68%2F98%2Fdb%2F6898db1da809a774f7ed36d4d7a82a6afd517465"
# Invalid Network_Resource_Name: "https://doi.org/10.5066/P9TK8KMM"
# Invalid Network_Resource_Name: "https://www.sciencebase.gov/catalog/item/62434c50d34e22d73748d366"
# Invalid Network_Resource_Name: "https://www.sciencebase.gov/catalog/file/get/62434c50d34e22d73748d366?f=__disk__20%2Fc9%2F37%2F20c93713022bcbe655c26bbac2ccca0dd3f3221a"
# Invalid Network_Resource_Name: "https://www.sciencebase.gov/catalog/file/get/62434c50d34e22d73748d366?f=__disk__ab%2F63%2Fd3%2Fab63d3d78ee5dc5c9dc7552d6d4fdbbaca9fb9a2"
# Invalid Network_Resource_Name: "https://www.sciencebase.gov/catalog/file/get/62434c50d34e22d73748d366?f=__disk__20%2Fc9%2F37%2F20c93713022bcbe655c26bbac2ccca0dd3f3221a"

# %% [markdown]
# ##### c.	Metadata explains field names and values contained in the dataset. Data tables, fields, and values must be explained clearly so that a non-specialist can understand them; verify that entity and attribute content of metadata (detailed section or data dictionary) corresponds to data set;

# %%
# List Entity and Attribute information from metadata file
for detailed in root.iter('detailed'):
 for enttyp in detailed.iter('enttyp'):
  enttypl = enttyp.find('enttypl')
  printmd ('**' + enttypl.text + "**")
  enttypd = enttyp.find('enttypd')
  printmd ('- ' + enttypd.text)
 for attr in detailed.findall('attr'):
  attrlabl = attr.find('attrlabl')
  print('\nattrlabl: ', attrlabl.text)
  attrdef = attr.find('attrdef')
  print('attrdef: ', attrdef.text)
  for attrdomv in attr.findall('attrdomv'):
    udom = attrdomv.find('udom')
    edom = attrdomv.find('edom')
    rdom = attrdomv.find('rdom')
    if udom != None:
     #print ('\t<Udom>')
     print('\t<udom>\t\t|-->', udom.text)
    if edom != None:
     for edom in attrdomv.findall('edom'):
      print ('\t<edom>')
      edomv = edom.find('edomv')
      print('\t\t<edomv>\t\t|-->', edomv.text)
      edomvd = edom.find('edomvd')
      print('\t\t\t<edomvd>\t|-->', edomvd.text)
      edomvds = edom.find('edomvds')      
      print('\t\t\t<edomvds>\t|-->', edomvds.text)   
    if rdom != None:  
     for rdom in attrdomv.findall('rdom'):
        print ('\t<rdom>')
        rdommin = rdom.find('rdommin')
        print('\t\t<rdomMIN>\t|-->', rdommin.text)
        rdommax = rdom.find('rdommax')
        print('\t\t<rdomMAX>\t|-->', rdommax.text)
# Out:
# **TotalMagneticIntensity.jpg**
# - Image of total magnetic intensity
# attrlabl:  Value
# attrdef:  Unique numeric values contained in each raster cell.
# 	<rdom>
# 		<rdomMIN>	|--> 0
# 		<rdomMAX>	|--> 255
# **Gap_TF3ANM.tif**
# - Raster geospatial data file.
# attrlabl:  nanoTesla
# attrdef:  Unique numeric values contained in each raster cell.
# 	<rdom>
# 		<rdomMIN>	|--> -675.17901611328
# 		<rdomMAX>	|--> 2774.9182128906
# **MO20F0196_USGS_GAP_MagneticFlightLineData.csv**
# - Dataset containing minimally processed (raw) magnetic data.
# attrlabl:  ALT
# attrdef:  WGS84 Altitude (metres AMSL)
# 	<rdom>
# 		<rdomMIN>	|--> 152.2
# 		<rdomMAX>	|--> 393.1
#
# attrlabl:  AZIMUTH
# attrdef:  Flight Line direction (ranged
# 	<rdom>
# 		<rdomMIN>	|--> -7.034545811279713e-05
# 		<rdomMAX>	|--> 360.00006438998673
#
# attrlabl:  DATE
# attrdef:  Flight Date (DD/MM/YYYY format - ASCII)
# 	<rdom>
# 		<rdomMIN>	|--> 2021.2027397260274
# 		<rdomMAX>	|--> 9999.0
#
# attrlabl:  DIUCON
# attrdef:  Consolidated Diurnal - using tied-in Backup Diurnal where required
# 	<rdom>
# 		<rdomMIN>	|--> 51121.95400035512
# 		<rdomMAX>	|--> 51187.86999974233
#
# attrlabl:  DIUEDIT
# attrdef:  Base Station Diurnal data (nT) -edited/de-spiked
# 	<rdom>
# 		<rdomMIN>	|--> 51121.95400035512
# 		<rdomMAX>	|--> 51589.95637066768
#
# attrlabl:  DIUEDIT2
# attrdef:  Backup Base Station Diurnal data (nT) -edited/de-spiked (if used)
# 	<rdom>
# 		<rdomMIN>	|--> 51016.36482638655
# 		<rdomMAX>	|--> 51201.7437218853
#
# attrlabl:  DIURNAL
# attrdef:  Base Station Diurnal data (nT) -measured
# 	<rdom>
# 		<rdomMIN>	|--> 50470.17693928254
# 		<rdomMAX>	|--> 51589.95637066768
#
# attrlabl:  DIURNAL2
# attrdef:  Backup Base Station Diurnal data (nT) -measured
# 	<rdom>
# 		<rdomMIN>	|--> 0.104939121256272
# 		<rdomMAX>	|--> 56176.57501070219
#
# attrlabl:  DTMFNL
# attrdef:  Final, corrected Digital Terrain Model  (m AMSL)
# 	<rdom>
# 		<rdomMIN>	|--> 16.994124314134982
# 		<rdomMAX>	|--> 291.7611925657331
#
# attrlabl:  FID
# attrdef:  Fiducial (UTC day-seconds)
# 	<rdom>
# 		<rdomMIN>	|--> 38367.80001458526
# 		<rdomMAX>	|--> 91681.40002070367
#
# attrlabl:  FLIGHT
# attrdef:  Flight Number
# 	<rdom>
# 		<rdomMIN>	|--> 13.0
# 		<rdomMAX>	|--> 96.0
#
# attrlabl:  HGEWFNL
# attrdef:  Final, measured East-West Magnetic gradient (nT/m)
# 	<rdom>
# 		<rdomMIN>	|--> -32.695221227227094
# 		<rdomMAX>	|--> 29.543117709894766
#
# attrlabl:  HGNSFNL
# attrdef:  Final, measured North-South Magnetic gradient (nT/m)
# 	<rdom>
# 		<rdomMIN>	|--> -14.266383609548317
# 		<rdomMAX>	|--> 18.791292674510498
#
# attrlabl:  IGRF_DEC
# attrdef:  IGRF Declination (Calculation date [2020 Coefficients]
# 	<rdom>
# 		<rdomMIN>	|--> -2.6538000191718356
# 		<rdomMAX>	|--> -1.7458
#
# attrlabl:  IGRF_INC
# attrdef:  IGRF Inclination (Calculation date [2020 Coefficients]
# 	<rdom>
# 		<rdomMIN>	|--> 64.91329998054505
# 		<rdomMAX>	|--> 66.08320003214628
#
# attrlabl:  IGRF_TF
# attrdef:  IGRF Total Field (Calculation date [2020 Coefficients]
# 	<rdom>
# 		<rdomMIN>	|--> 50774.05899336586
# 		<rdomMAX>	|--> 51573.83920643823
#
# attrlabl:  JULIAN
# attrdef:  Year+Julian Day
# 	<rdom>
# 		<rdomMIN>	|--> 202175.0
# 		<rdomMAX>	|--> 2021194.0
#
# attrlabl:  LAT
# attrdef:  Latitude (decimal degrees)
# 	<rdom>
# 		<rdomMIN>	|--> 36.83041508577423
# 		<rdomMAX>	|--> 38.29528422465964
#
# attrlabl:  LINE
# attrdef:  Line Number (ASCII; Prefix L
# 	<rdom>
# 		<rdomMIN>	|--> 1e+32
# 		<rdomMAX>	|--> -1e+32
#
# attrlabl:  LON
# attrdef:  Longitude (decimal degrees)
# 	<rdom>
# 		<rdomMIN>	|--> -89.95097715657224
# 		<rdomMAX>	|--> -88.83967198411617
#
# attrlabl:  RADAR
# attrdef:  Radar Altimeter (metres AGL)
# 	<rdom>
# 		<rdomMIN>	|--> 59.601561401367185
# 		<rdomMAX>	|--> 227.20222607421874
#
# attrlabl:  RADFNL
# attrdef:  Radar Altimeter corrected for system lag (metres AGL)
# 	<rdom>
# 		<rdomMIN>	|--> 59.15603038641735
# 		<rdomMAX>	|--> 226.30629546657067
#
# attrlabl:  TF1CMP
# attrdef:  Raw, Compensated TMI (Left WingTip, nT)
# 	<rdom>
# 		<rdomMIN>	|--> 42078.1597
# 		<rdomMAX>	|--> 54049.92578125
#
# attrlabl:  TF1CMPEDIT
# attrdef:  Edited (de-Spiked), Compensated TMI (Left WingTip, nT)
# 	<rdom>
# 		<rdomMIN>	|--> 50163.4140625
# 		<rdomMAX>	|--> 54049.92578125
#
# attrlabl:  TF1UNC
# attrdef:  Raw, Uncompensated TMI (Left WingTip, nT)
# 	<rdom>
# 		<rdomMIN>	|--> 42053.23046875
# 		<rdomMAX>	|--> 54038.296875
#
# attrlabl:  TF2CMP
# attrdef:  Raw, Compensated TMI (Right WingTip, nT)
# 	<rdom>
# 		<rdomMIN>	|--> 50179.30078125
# 		<rdomMAX>	|--> 53715.78515625
#
# attrlabl:  TF2CMPEDIT
# attrdef:  Edited (de-Spiked), Compensated TMI (Right WingTip, nT)
# 	<rdom>
# 		<rdomMIN>	|--> 50179.30078125
# 		<rdomMAX>	|--> 53715.78515625
#
# attrlabl:  TF2UNC
# attrdef:  Raw, Uncompensated TMI (Right WingTip, nT)
# 	<rdom>
# 		<rdomMIN>	|--> 50166.77734375
# 		<rdomMAX>	|--> 53710.0390625
#
# attrlabl:  TF3ANM
# attrdef:  Anomalous TMI (IGRF corrected, nT)
# 	<rdom>
# 		<rdomMIN>	|--> -683.8045732156461
# 		<rdomMAX>	|--> 2840.466988677508
#
# attrlabl:  TF3CMP
# attrdef:  Raw, Compensated TMI (Tail, nT) - Principal Magnetometer
# 	<rdom>
# 		<rdomMIN>	|--> 50195.15625
# 		<rdomMAX>	|--> 53841.99609375
#
# attrlabl:  TF3CMPEDIT
# attrdef:  Edited (de-Spiked), Compensated TMI (Tail, nT) - Principal Magnetometer
# 	<rdom>
# 		<rdomMIN>	|--> 50195.15625
# 		<rdomMAX>	|--> 53841.99609375
#
# attrlabl:  TF3DIU
# attrdef:  Diurnal corrected Tail TMI (nT)
# 	<rdom>
# 		<rdomMIN>	|--> 50208.47791175082
# 		<rdomMAX>	|--> 53863.16590563662
#
# attrlabl:  TF3FNL
# attrdef:  Final (micro-levelled) TMI (nT)
# 	<rdom>
# 		<rdomMIN>	|--> 50203.813361602384
# 		<rdomMAX>	|--> 53862.01928863233
#
# attrlabl:  TF3LVL
# attrdef:  Tie-line intersection levelled TMI (nT)
# 	<rdom>
# 		<rdomMIN>	|--> 50208.03743026934
# 		<rdomMAX>	|--> 53863.311313044025
#
# attrlabl:  TF3UNC
# attrdef:  Raw, Uncompensated TMI (Tail, nT) - Principal Magnetometer
# 	<rdom>
# 		<rdomMIN>	|--> 50188.890625
# 		<rdomMAX>	|--> 53834.140625
#
# attrlabl:  TIME
# attrdef:  UTC TIME (hh
# 	<rdom>
# 		<rdomMIN>	|--> 10.657722226273682
# 		<rdomMAX>	|--> 25.467055561306577
#
# attrlabl:  VMX
# attrdef:  Fluxgate X component (nT)
# 	<rdom>
# 		<rdomMIN>	|--> -51599.0625
# 		<rdomMAX>	|--> -15652.5712890625
#
# attrlabl:  VMY
# attrdef:  Fluxgate Y component (nT)
# 	<rdom>
# 		<rdomMIN>	|--> -34583.1328125
# 		<rdomMAX>	|--> 17154.3359375
#
# attrlabl:  VMZ
# attrdef:  Fluxgate Z component (nT)
# 	<rdom>
# 		<rdomMIN>	|--> -48452.1484375
# 		<rdomMAX>	|--> 49264.515625
#
# attrlabl:  X_UTM_TRIM
# attrdef:  UTM Easting - WGS84, UTM Zone 16N (metres) - trimmed for line overlap
# 	<rdom>
# 		<rdomMIN>	|--> 236824.4340386539
# 		<rdomMAX>	|--> 335993.89589584223
#
# attrlabl:  X_UTM_WIN
# attrdef:  UTM Easting - WGS84, UTM Zone 16N (metres)
# 	<rdom>
# 		<rdomMIN>	|--> 236824.4340386539
# 		<rdomMAX>	|--> 335993.89589584223
#
# attrlabl:  Y_UTM_TRIM
# attrdef:  UTM Northing - WGS84, UTM Zone 16N (metres) - trimmed for line overlap
# 	<rdom>
# 		<rdomMIN>	|--> 4080094.457927594
# 		<rdomMAX>	|--> 4240292.028284814
#
# attrlabl:  Y_UTM_WIN
# attrdef:  UTM Northing - WGS84, UTM Zone 16N (metres)
# 	<rdom>
# 		<rdomMIN>	|--> 4080094.457927594
# 		<rdomMAX>	|--> 4240292.028284814

# %%
# Read in csv data set to check min and max of lat and long:
ChildPath = r"C:\CurrentWork\DataReleaseReviews\IP-139541Gap\MagChild"
csvFileName1 = "MO20F0196_USGS_GAP_MagneticFlightLineData.csv"
csvFileName2 = "APEX_2018_2020_bNMR_Inverted_Models.csv"
csvFileName3 = "APEX_2018_2020_bNMR_T2.csv"

csvFilePath1 = ChildPath + "\\" + csvFileName1
csvFilePath2 = ChildPath + "\\" + csvFileName2
csvFilePath3 = ChildPath + "\\" + csvFileName3

datdicFileName1 = "MO20F0196_GAP_DataDictionary_MAG_data.json"
datdicFilePath1 = ChildPath + "\\" + datdicFileName1
print ('The Data Dictionary File Path is ' + datdicFilePath1)

#datdicFileName2 = "bNMR_Inverted_Models_data_dictionary.csv"
#datdicFilePath2 = ChildPath + "\\" + datdicFileName2
#print ('The Data Dictionary File Path is ' + datdicFilePath2)

#datdicFileName3 = "bNMR_T2_data_dictionary.csv"
#datdicFilePath3 = ChildPath + "\\" + datdicFileName3
#print ('The Data Dictionary File Path is ' + datdicFilePath3)
# Out:
# The Data Dictionary File Path is C:\CurrentWork\DataReleaseReviews\IP-139541Gap\MagChild\MO20F0196_GAP_DataDictionary_MAG_data.json

# %%
    #Open the json file
with open(datdicFilePath1) as f:
 jsonData = json.load(f)
pretty_object = json.dumps(jsonData, indent=4)
print(pretty_object)
# Out:
# {
#     "dataset_info": {
#         "channel_list": [
#             "ALT",
#             "AZIMUTH",
#             "DATE",
#             "DIUCON",
#             "DIUEDIT",
#             "DIUEDIT2",
#             "DIURNAL",
#             "DIURNAL2",
#             "DTMFNL",
#             "FID",
#             "FLIGHT",
#             "HGEWFNL",
#             "HGNSFNL",
#             "IGRF_DEC",
#             "IGRF_INC",
#             "IGRF_TF",
#             "JULIAN",
#             "LAT",
#             "LINE",
#             "LON",
#             "RADAR",
#             "RADFNL",
#             "TF1CMP",
#             "TF1CMPEDIT",
#             "TF1UNC",
#             "TF2CMP",
#             "TF2CMPEDIT",
#             "TF2UNC",
#             "TF3ANM",
#             "TF3CMP",
#             "TF3CMPEDIT",
#             "TF3DIU",
#             "TF3FNL",
#             "TF3LVL",
#             "TF3UNC",
#             "TIME",
#             "VMX",
#             "VMY",
#             "VMZ",
#             "X_UTM_TRIM",
#             "X_UTM_WIN",
#             "Y_UTM_TRIM",
#             "Y_UTM_WIN"
#         ],
#         "coordinate_system": {
#             "crs": [
#                 "AUTHORITY[\"EPSG\"",
#                 "32616]]"
#             ],
#             "datum": "WGS 84",
#             "name": "WGS 84 / UTM zone 16N",
#             "proj_string": "WGS 84 / UTM zone 16N",
#             "projection": "\"Transverse Mercator\",0,-87,0.9996,500000,0",
#             "type": "Geosoft",
#             "unit": "m"
#         },
#         "file_ext": ".gdb",
#         "file_type": "Geosoft Database",
#         "surveyline_num_max": 6410,
#         "surveyline_num_min": 20,
#         "tieline_num_max": 10291,
#         "tieline_num_min": 10010,
#         "x_max_utm": 335985.3365200461,
#         "x_min_utm": 236824.4340386539,
#         "y_max_utm": 4240292.028284814,
#         "y_min_utm": 4080094.457927594
#     },
#     "fields": {
#         "ALT": {
#             "array": 1,
#             "chan_max": 393.1,
#             "chan_min": 152.2,
#             "description": "WGS84 Altitude (metres AMSL)",
#             "label": "ALT",
#             "name": "ALT",
#             "unit": "m"
#         },
#         "AZIMUTH": {
#             "array": 1,
#             "chan_max": 360.00006438998673,
#             "chan_min": -7.034545811279713e-05,
#             "description": "Flight Line direction (ranged",
#             "label": "AZIMUTH",
#             "name": "AZIMUTH",
#             "unit": "deg"
#         },
#         "DATE": {
#             "array": 1,
#             "chan_max": 9999.0,
#             "chan_min": 2021.2027397260274,
#             "description": "Flight Date (DD/MM/YYYY format - ASCII)",
#             "label": "DATE",
#             "name": "DATE",
#             "unit": "yyyymmdd"
#         },
#         "DIUCON": {
#             "array": 1,
#             "chan_max": 51187.86999974233,
#             "chan_min": 51121.95400035512,
#             "description": "Consolidated Diurnal - using tied-in Backup Diurnal where required",
#             "label": "DIUCON",
#             "name": "DIUCON",
#             "unit": "nT"
#         },
#         "DIUEDIT": {
#             "array": 1,
#             "chan_max": 51589.95637066768,
#             "chan_min": 51121.95400035512,
#             "description": "Base Station Diurnal data (nT) -edited/de-spiked",
#             "label": "DIUEDIT",
#             "name": "DIUEDIT",
#             "unit": "nT"
#         },
#         "DIUEDIT2": {
#             "array": 1,
#             "chan_max": 51201.7437218853,
#             "chan_min": 51016.36482638655,
#             "description": "Backup Base Station Diurnal data (nT) -edited/de-spiked (if used)",
#             "label": "DIUEDIT2",
#             "name": "DIUEDIT2",
#             "unit": "nT"
#         },
#         "DIURNAL": {
#             "array": 1,
#             "chan_max": 51589.95637066768,
#             "chan_min": 50470.17693928254,
#             "description": "Base Station Diurnal data (nT) -measured",
#             "label": "DIURNAL",
#             "name": "DIURNAL",
#             "unit": "nT"
#         },
#         "DIURNAL2": {
#             "array": 1,
#             "chan_max": 56176.57501070219,
#             "chan_min": 0.104939121256272,
#             "description": "Backup Base Station Diurnal data (nT) -measured",
#             "label": "DIURNAL2",
#             "name": "DIURNAL2",
#             "unit": "nT"
#         },
#         "DTMFNL": {
#             "array": 1,
#             "chan_max": 291.7611925657331,
#             "chan_min": 16.994124314134982,
#             "description": "Final, corrected Digital Terrain Model  (m AMSL)",
#             "label": "DTMFNL",
#             "name": "DTMFNL",
#             "unit": "m"
#         },
#         "FID": {
#             "array": 1,
#             "chan_max": 91681.40002070367,
#             "chan_min": 38367.80001458526,
#             "description": "Fiducial (UTC day-seconds)",
#             "label": "FID",
#             "name": "FID",
#             "unit": "id"
#         },
#         "FLIGHT": {
#             "array": 1,
#             "chan_max": 96.0,
#             "chan_min": 13.0,
#             "description": "Flight Number",
#             "label": "FLIGHT",
#             "name": "FLIGHT",
#             "unit": "n/a"
#         },
#         "HGEWFNL": {
#             "array": 1,
#             "chan_max": 29.543117709894766,
#             "chan_min": -32.695221227227094,
#             "description": "Final, measured East-West Magnetic gradient (nT/m)",
#             "label": "HGEWFNL",
#             "name": "HGEWFNL",
#             "unit": "nT/m"
#         },
#         "HGNSFNL": {
#             "array": 1,
#             "chan_max": 18.791292674510498,
#             "chan_min": -14.266383609548317,
#             "description": "Final, measured North-South Magnetic gradient (nT/m)",
#             "label": "HGNSFNL",
#             "name": "HGNSFNL",
#             "unit": "nT/m"
#         },
#         "IGRF_DEC": {
#             "array": 1,
#             "chan_max": -1.7458,
#             "chan_min": -2.6538000191718356,
#             "description": "IGRF Declination (Calculation date [2020 Coefficients]",
#             "label": "IGRF_DEC",
#             "name": "IGRF_DEC",
#             "unit": "deg"
#         },
#         "IGRF_INC": {
#             "array": 1,
#             "chan_max": 66.08320003214628,
#             "chan_min": 64.91329998054505,
#             "description": "IGRF Inclination (Calculation date [2020 Coefficients]",
#             "label": "IGRF_INC",
#             "name": "IGRF_INC",
#             "unit": "deg"
#         },
#         "IGRF_TF": {
#             "array": 1,
#             "chan_max": 51573.83920643823,
#             "chan_min": 50774.05899336586,
#             "description": "IGRF Total Field (Calculation date [2020 Coefficients]",
#             "label": "IGRF_TF",
#             "name": "IGRF_TF",
#             "unit": "nT"
#         },
#         "JULIAN": {
#             "array": 1,
#             "chan_max": 2021194.0,
#             "chan_min": 202175.0,
#             "description": "Year+Julian Day",
#             "label": "JULIAN",
#             "name": "JULIAN",
#             "unit": "Year+Julian Day"
#         },
#         "LAT": {
#             "array": 1,
#             "chan_max": 38.29528422465964,
#             "chan_min": 36.83041508577423,
#             "description": "Latitude (decimal degrees)",
#             "label": "LAT",
#             "name": "LAT",
#             "unit": "dega"
#         },
#         "LINE": {
#             "array": 1,
#             "chan_max": -1e+32,
#             "chan_min": 1e+32,
#             "description": "Line Number (ASCII; Prefix L",
#             "label": "LINE",
#             "name": "LINE",
#             "unit": "id"
#         },
#         "LON": {
#             "array": 1,
#             "chan_max": -88.83967198411617,
#             "chan_min": -89.95097715657224,
#             "description": "Longitude (decimal degrees)",
#             "label": "LON",
#             "name": "LON",
#             "unit": "dega"
#         },
#         "RADAR": {
#             "array": 1,
#             "chan_max": 227.20222607421874,
#             "chan_min": 59.601561401367185,
#             "description": "Radar Altimeter (metres AGL)",
#             "label": "RADAR",
#             "name": "RADAR",
#             "unit": "m"
#         },
#         "RADFNL": {
#             "array": 1,
#             "chan_max": 226.30629546657067,
#             "chan_min": 59.15603038641735,
#             "description": "Radar Altimeter corrected for system lag (metres AGL)",
#             "label": "RADFNL",
#             "name": "RADFNL",
#             "unit": "m"
#         },
#         "TF1CMP": {
#             "array": 1,
#             "chan_max": 54049.92578125,
#             "chan_min": 42078.1597,
#             "description": "Raw, Compensated TMI (Left WingTip, nT)",
#             "label": "TF1CMP",
#             "name": "TF1CMP",
#             "unit": "nT"
#         },
#         "TF1CMPEDIT": {
#             "array": 1,
#             "chan_max": 54049.92578125,
#             "chan_min": 50163.4140625,
#             "description": "Edited (de-Spiked), Compensated TMI (Left WingTip, nT)",
#             "label": "TF1CMPEDIT",
#             "name": "TF1CMPEDIT",
#             "unit": "nT"
#         },
#         "TF1UNC": {
#             "array": 1,
#             "chan_max": 54038.296875,
#             "chan_min": 42053.23046875,
#             "description": "Raw, Uncompensated TMI (Left WingTip, nT)",
#             "label": "TF1UNC",
#             "name": "TF1UNC",
#             "unit": "nT"
#         },
#         "TF2CMP": {
#             "array": 1,
#             "chan_max": 53715.78515625,
#             "chan_min": 50179.30078125,
#             "description": "Raw, Compensated TMI (Right WingTip, nT)",
#             "label": "TF2CMP",
#             "name": "TF2CMP",
#             "unit": "nT"
#         },
#         "TF2CMPEDIT": {
#             "array": 1,
#             "chan_max": 53715.78515625,
#             "chan_min": 50179.30078125,
#             "description": "Edited (de-Spiked), Compensated TMI (Right WingTip, nT)",
#             "label": "TF2CMPEDIT",
#             "name": "TF2CMPEDIT",
#             "unit": "nT"
#         },
#         "TF2UNC": {
#             "array": 1,
#             "chan_max": 53710.0390625,
#             "chan_min": 50166.77734375,
#             "description": "Raw, Uncompensated TMI (Right WingTip, nT)",
#             "label": "TF2UNC",
#             "name": "TF2UNC",
#             "unit": "nT"
#         },
#         "TF3ANM": {
#             "array": 1,
#             "chan_max": 2840.466988677508,
#             "chan_min": -683.8045732156461,
#             "description": "Anomalous TMI (IGRF corrected, nT)",
#             "label": "TF3ANM",
#             "name": "TF3ANM",
#             "unit": "nT"
#         },
#         "TF3CMP": {
#             "array": 1,
#             "chan_max": 53841.99609375,
#             "chan_min": 50195.15625,
#             "description": "Raw, Compensated TMI (Tail, nT) - Principal Magnetometer",
#             "label": "TF3CMP",
#             "name": "TF3CMP",
#             "unit": "nT"
#         },
#         "TF3CMPEDIT": {
#             "array": 1,
#             "chan_max": 53841.99609375,
#             "chan_min": 50195.15625,
#             "description": "Edited (de-Spiked), Compensated TMI (Tail, nT) - Principal Magnetometer",
#             "label": "TF3CMPEDIT",
#             "name": "TF3CMPEDIT",
#             "unit": "nT"
#         },
#         "TF3DIU": {
#             "array": 1,
#             "chan_max": 53863.16590563662,
#             "chan_min": 50208.47791175082,
#             "description": "Diurnal corrected Tail TMI (nT)",
#             "label": "TF3DIU",
#             "name": "TF3DIU",
#             "unit": "nT"
#         },
#         "TF3FNL": {
#             "array": 1,
#             "chan_max": 53862.01928863233,
#             "chan_min": 50203.813361602384,
#             "description": "Final (micro-levelled) TMI (nT)",
#             "label": "TF3FNL",
#             "name": "TF3FNL",
#             "unit": "nT"
#         },
#         "TF3LVL": {
#             "array": 1,
#             "chan_max": 53863.311313044025,
#             "chan_min": 50208.03743026934,
#             "description": "Tie-line intersection levelled TMI (nT)",
#             "label": "TF3LVL",
#             "name": "TF3LVL",
#             "unit": "nT"
#         },
#         "TF3UNC": {
#             "array": 1,
#             "chan_max": 53834.140625,
#             "chan_min": 50188.890625,
#             "description": "Raw, Uncompensated TMI (Tail, nT) - Principal Magnetometer",
#             "label": "TF3UNC",
#             "name": "TF3UNC",
#             "unit": "nT"
#         },
#         "TIME": {
#             "array": 1,
#             "chan_max": 25.467055561306577,
#             "chan_min": 10.657722226273682,
#             "description": "UTC TIME (hh",
#             "label": "TIME",
#             "name": "TIME",
#             "unit": "hh:mm:ss.ss"
#         },
#         "VMX": {
#             "array": 1,
#             "chan_max": -15652.5712890625,
#             "chan_min": -51599.0625,
#             "description": "Fluxgate X component (nT)",
#             "label": "VMX",
#             "name": "VMX",
#             "unit": "nT"
#         },
#         "VMY": {
#             "array": 1,
#             "chan_max": 17154.3359375,
#             "chan_min": -34583.1328125,
#             "description": "Fluxgate Y component (nT)",
#             "label": "VMY",
#             "name": "VMY",
#             "unit": "nT"
#         },
#         "VMZ": {
#             "array": 1,
#             "chan_max": 49264.515625,
#             "chan_min": -48452.1484375,
#             "description": "Fluxgate Z component (nT)",
#             "label": "VMZ",
#             "name": "VMZ",
#             "unit": "nT"
#         },
#         "X_UTM_TRIM": {
#             "array": 1,
#             "chan_max": 335993.89589584223,
#             "chan_min": 236824.4340386539,
#             "description": "UTM Easting - WGS84, UTM Zone 16N (metres) - trimmed for line overlap",
#             "label": "X_UTM_TRIM",
#             "name": "X_UTM_TRIM",
#             "unit": "m"
#         },
#         "X_UTM_WIN": {
#             "array": 1,
#             "chan_max": 335993.89589584223,
#             "chan_min": 236824.4340386539,
#             "description": "UTM Easting - WGS84, UTM Zone 16N (metres)",
#             "label": "X_UTM_WIN",
#             "name": "X_UTM_WIN",
#             "unit": "m"
#         },
#         "Y_UTM_TRIM": {
#             "array": 1,
#             "chan_max": 4240292.028284814,
#             "chan_min": 4080094.457927594,
#             "description": "UTM Northing - WGS84, UTM Zone 16N (metres) - trimmed for line overlap",
#             "label": "Y_UTM_TRIM",
#             "name": "Y_UTM_TRIM",
#             "unit": "m"
#         },
#         "Y_UTM_WIN": {
#             "array": 1,
#             "chan_max": 4240292.028284814,
#             "chan_min": 4080094.457927594,
#             "description": "UTM Northing - WGS84, UTM Zone 16N (metres)",
#             "label": "Y_UTM_WIN",
#             "name": "Y_UTM_WIN",
#             "unit": "m"
#         }
#     },
#     "key_mapping": {
#         "fiducial": "FID",
#         "height": "RADAR",
#         "line_number": "LINE",
#         "x": "X_UTM_TRIM",
#         "y": "Y_UTM_TRIM",
#         "z": "DTMFNL"
#     }
# }

# %%
print(type(jsonData))
for item in jsonData['dataset_info']:
    print (item)
# Out:
# <class 'dict'>
# channel_list
# coordinate_system
# file_ext
# file_type
# surveyline_num_max
# surveyline_num_min
# tieline_num_max
# tieline_num_min
# x_max_utm
# x_min_utm
# y_max_utm
# y_min_utm

# %%
# Create arrays of JSON data to be inserted into metadata.
#print(jsonData['fields']['ALT']['description'])
arrFields = []
arrDescription = []
arrUnit = []
arrCsvMax = []
arrCsvMin = []

for item in jsonData['fields']:
    #print (item)
    arrFields.append(item)
    arrDescription.append(jsonData['fields'][item]['description'])
    arrUnit.append(jsonData['fields'][item]['unit'])
    arrCsvMax.append(jsonData['fields'][item]['chan_max'])
    arrCsvMin.append(jsonData['fields'][item]['chan_min'])
print('JASON Arrays created for Entity and Attribute Creation')
# Out:
# JASON Arrays created for Entity and Attribute Creation

# %%
for i in range(len(arrFields)):
    print (arrFields[i],',',arrDescription[i],',',arrUnit[i])
# Out:
# ALT , WGS84 Altitude (metres AMSL) , m
# AZIMUTH , Flight Line direction (ranged , deg
# DATE , Flight Date (DD/MM/YYYY format - ASCII) , yyyymmdd
# DIUCON , Consolidated Diurnal - using tied-in Backup Diurnal where required , nT
# DIUEDIT , Base Station Diurnal data (nT) -edited/de-spiked , nT
# DIUEDIT2 , Backup Base Station Diurnal data (nT) -edited/de-spiked (if used) , nT
# DIURNAL , Base Station Diurnal data (nT) -measured , nT
# DIURNAL2 , Backup Base Station Diurnal data (nT) -measured , nT
# DTMFNL , Final, corrected Digital Terrain Model  (m AMSL) , m
# FID , Fiducial (UTC day-seconds) , id
# FLIGHT , Flight Number , n/a
# HGEWFNL , Final, measured East-West Magnetic gradient (nT/m) , nT/m
# HGNSFNL , Final, measured North-South Magnetic gradient (nT/m) , nT/m
# IGRF_DEC , IGRF Declination (Calculation date [2020 Coefficients] , deg
# IGRF_INC , IGRF Inclination (Calculation date [2020 Coefficients] , deg
# IGRF_TF , IGRF Total Field (Calculation date [2020 Coefficients] , nT
# JULIAN , Year+Julian Day , Year+Julian Day
# LAT , Latitude (decimal degrees) , dega
# LINE , Line Number (ASCII; Prefix L , id
# LON , Longitude (decimal degrees) , dega
# RADAR , Radar Altimeter (metres AGL) , m
# RADFNL , Radar Altimeter corrected for system lag (metres AGL) , m
# TF1CMP , Raw, Compensated TMI (Left WingTip, nT) , nT
# TF1CMPEDIT , Edited (de-Spiked), Compensated TMI (Left WingTip, nT) , nT
# TF1UNC , Raw, Uncompensated TMI (Left WingTip, nT) , nT
# TF2CMP , Raw, Compensated TMI (Right WingTip, nT) , nT
# TF2CMPEDIT , Edited (de-Spiked), Compensated TMI (Right WingTip, nT) , nT
# TF2UNC , Raw, Uncompensated TMI (Right WingTip, nT) , nT
# TF3ANM , Anomalous TMI (IGRF corrected, nT) , nT
# TF3CMP , Raw, Compensated TMI (Tail, nT) - Principal Magnetometer , nT
# TF3CMPEDIT , Edited (de-Spiked), Compensated TMI (Tail, nT) - Principal Magnetometer , nT
# TF3DIU , Diurnal corrected Tail TMI (nT) , nT
# TF3FNL , Final (micro-levelled) TMI (nT) , nT
# TF3LVL , Tie-line intersection levelled TMI (nT) , nT
# TF3UNC , Raw, Uncompensated TMI (Tail, nT) - Principal Magnetometer , nT
# TIME , UTC TIME (hh , hh:mm:ss.ss
# VMX , Fluxgate X component (nT) , nT
# VMY , Fluxgate Y component (nT) , nT
# VMZ , Fluxgate Z component (nT) , nT
# X_UTM_TRIM , UTM Easting - WGS84, UTM Zone 16N (metres) - trimmed for line overlap , m
# X_UTM_WIN , UTM Easting - WGS84, UTM Zone 16N (metres) , m
# Y_UTM_TRIM , UTM Northing - WGS84, UTM Zone 16N (metres) - trimmed for line overlap , m
# Y_UTM_WIN , UTM Northing - WGS84, UTM Zone 16N (metres) , m

# %%
print(jsonData)
# Out:
# {'dataset_info': {'channel_list': ['ALT', 'AZIMUTH', 'DATE', 'DIUCON', 'DIUEDIT', 'DIUEDIT2', 'DIURNAL', 'DIURNAL2', 'DTMFNL', 'FID', 'FLIGHT', 'HGEWFNL', 'HGNSFNL', 'IGRF_DEC', 'IGRF_INC', 'IGRF_TF', 'JULIAN', 'LAT', 'LINE', 'LON', 'RADAR', 'RADFNL', 'TF1CMP', 'TF1CMPEDIT', 'TF1UNC', 'TF2CMP', 'TF2CMPEDIT', 'TF2UNC', 'TF3ANM', 'TF3CMP', 'TF3CMPEDIT', 'TF3DIU', 'TF3FNL', 'TF3LVL', 'TF3UNC', 'TIME', 'VMX', 'VMY', 'VMZ', 'X_UTM_TRIM', 'X_UTM_WIN', 'Y_UTM_TRIM', 'Y_UTM_WIN'], 'coordinate_system': {'crs': ['AUTHORITY["EPSG"', '32616]]'], 'datum': 'WGS 84', 'name': 'WGS 84 / UTM zone 16N', 'proj_string': 'WGS 84 / UTM zone 16N', 'projection': '"Transverse Mercator",0,-87,0.9996,500000,0', 'type': 'Geosoft', 'unit': 'm'}, 'file_ext': '.gdb', 'file_type': 'Geosoft Database', 'surveyline_num_max': 6410, 'surveyline_num_min': 20, 'tieline_num_max': 10291, 'tieline_num_min': 10010, 'x_max_utm': 335985.3365200461, 'x_min_utm': 236824.4340386539, 'y_max_utm': 4240292.028284814, 'y_min_utm': 4080094.457927594}, 'fields': {'ALT': {'array': 1, 'chan_max': 393.1, 'chan_min': 152.2, 'description': 'WGS84 Altitude (metres AMSL)', 'label': 'ALT', 'name': 'ALT', 'unit': 'm'}, 'AZIMUTH': {'array': 1, 'chan_max': 360.00006438998673, 'chan_min': -7.034545811279713e-05, 'description': 'Flight Line direction (ranged', 'label': 'AZIMUTH', 'name': 'AZIMUTH', 'unit': 'deg'}, 'DATE': {'array': 1, 'chan_max': 9999.0, 'chan_min': 2021.2027397260274, 'description': 'Flight Date (DD/MM/YYYY format - ASCII)', 'label': 'DATE', 'name': 'DATE', 'unit': 'yyyymmdd'}, 'DIUCON': {'array': 1, 'chan_max': 51187.86999974233, 'chan_min': 51121.95400035512, 'description': 'Consolidated Diurnal - using tied-in Backup Diurnal where required', 'label': 'DIUCON', 'name': 'DIUCON', 'unit': 'nT'}, 'DIUEDIT': {'array': 1, 'chan_max': 51589.95637066768, 'chan_min': 51121.95400035512, 'description': 'Base Station Diurnal data (nT) -edited/de-spiked', 'label': 'DIUEDIT', 'name': 'DIUEDIT', 'unit': 'nT'}, 'DIUEDIT2': {'array': 1, 'chan_max': 51201.7437218853, 'chan_min': 51016.36482638655, 'description': 'Backup Base Station Diurnal data (nT) -edited/de-spiked (if used)', 'label': 'DIUEDIT2', 'name': 'DIUEDIT2', 'unit': 'nT'}, 'DIURNAL': {'array': 1, 'chan_max': 51589.95637066768, 'chan_min': 50470.17693928254, 'description': 'Base Station Diurnal data (nT) -measured', 'label': 'DIURNAL', 'name': 'DIURNAL', 'unit': 'nT'}, 'DIURNAL2': {'array': 1, 'chan_max': 56176.57501070219, 'chan_min': 0.104939121256272, 'description': 'Backup Base Station Diurnal data (nT) -measured', 'label': 'DIURNAL2', 'name': 'DIURNAL2', 'unit': 'nT'}, 'DTMFNL': {'array': 1, 'chan_max': 291.7611925657331, 'chan_min': 16.994124314134982, 'description': 'Final, corrected Digital Terrain Model  (m AMSL)', 'label': 'DTMFNL', 'name': 'DTMFNL', 'unit': 'm'}, 'FID': {'array': 1, 'chan_max': 91681.40002070367, 'chan_min': 38367.80001458526, 'description': 'Fiducial (UTC day-seconds)', 'label': 'FID', 'name': 'FID', 'unit': 'id'}, 'FLIGHT': {'array': 1, 'chan_max': 96.0, 'chan_min': 13.0, 'description': 'Flight Number', 'label': 'FLIGHT', 'name': 'FLIGHT', 'unit': 'n/a'}, 'HGEWFNL': {'array': 1, 'chan_max': 29.543117709894766, 'chan_min': -32.695221227227094, 'description': 'Final, measured East-West Magnetic gradient (nT/m)', 'label': 'HGEWFNL', 'name': 'HGEWFNL', 'unit': 'nT/m'}, 'HGNSFNL': {'array': 1, 'chan_max': 18.791292674510498, 'chan_min': -14.266383609548317, 'description': 'Final, measured North-South Magnetic gradient (nT/m)', 'label': 'HGNSFNL', 'name': 'HGNSFNL', 'unit': 'nT/m'}, 'IGRF_DEC': {'array': 1, 'chan_max': -1.7458, 'chan_min': -2.6538000191718356, 'description': 'IGRF Declination (Calculation date [2020 Coefficients]', 'label': 'IGRF_DEC', 'name': 'IGRF_DEC', 'unit': 'deg'}, 'IGRF_INC': {'array': 1, 'chan_max': 66.08320003214628, 'chan_min': 64.91329998054505, 'description': 'IGRF Inclination (Calculation date [2020 Coefficients]', 'label': 'IGRF_INC', 'name': 'IGRF_INC', 'unit': 'deg'}, 'IGRF ...

# %%
print(jsonData['dataset_info']['channel_list'])
# Out:
# ['ALT', 'AZIMUTH', 'DATE', 'DIUCON', 'DIUEDIT', 'DIUEDIT2', 'DIURNAL', 'DIURNAL2', 'DTMFNL', 'FID', 'FLIGHT', 'HGEWFNL', 'HGNSFNL', 'IGRF_DEC', 'IGRF_INC', 'IGRF_TF', 'JULIAN', 'LAT', 'LINE', 'LON', 'RADAR', 'RADFNL', 'TF1CMP', 'TF1CMPEDIT', 'TF1UNC', 'TF2CMP', 'TF2CMPEDIT', 'TF2UNC', 'TF3ANM', 'TF3CMP', 'TF3CMPEDIT', 'TF3DIU', 'TF3FNL', 'TF3LVL', 'TF3UNC', 'TIME', 'VMX', 'VMY', 'VMZ', 'X_UTM_TRIM', 'X_UTM_WIN', 'Y_UTM_TRIM', 'Y_UTM_WIN']

# %%
# read file into pandas; note that can take over 1 minute depending on the size of the CSV file and computing power.
#for more on pandas visit https://pandas.pydata.org/

csvDataFrame = pd.read_csv(csvFilePath1, sep=',', delimiter=None, header='infer', names=None, index_col=None, usecols=None, squeeze=False, prefix=None, mangle_dupe_cols=True, dtype=None, engine=None, converters=None, true_values=None, false_values=None, skipinitialspace=False, skiprows=None, nrows=None, na_values=None, keep_default_na=True, na_filter=True, verbose=False, skip_blank_lines=True, parse_dates=False, infer_datetime_format=False, keep_date_col=False, date_parser=None, dayfirst=False, iterator=False, chunksize=None, compression='infer', thousands=None, decimal=b'.', lineterminator=None, quotechar='"', quoting=0, doublequote=True, escapechar=None, comment=None, encoding=None, dialect=None, error_bad_lines=True, warn_bad_lines=True, delim_whitespace=False, low_memory=True, memory_map=False, float_precision=None)
csvDataFrame
# Out:
# C:\Users\pbrown\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\pbrown\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: FutureWarning: The warn_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                 ALT     AZIMUTH        DATE        DIUCON       DIUEDIT  \
# 0        245.800000   91.153312  2021/03/22  51149.667700  51149.667700
# 1        245.800000   91.222613  2021/03/22  51149.667000  51149.667000
# 2        245.800000   91.312395  2021/03/22  51149.675500  51149.675500
# 3        245.799999   91.408711  2021/03/22  51149.684000  51149.684000
# 4        245.700001   91.521824  2021/03/22  51149.692500  51149.692500
# ...             ...         ...         ...           ...           ...
# 8586393  282.999958  180.935526  2021/03/22  51185.561801  51185.561801
# 8586394  282.799958  180.913681  2021/03/22  51185.568000  51185.568000
# 8586395  282.599958  180.888283  2021/03/22  51185.568800  51185.568800
# 8586396  282.399958  180.855573  2021/03/22  51185.569600  51185.569600
# 8586397  282.199938  180.816056  2021/03/22  51185.570400  51185.570400
#
#              DIUEDIT2       DIURNAL      DIURNAL2      DTMFNL           FID  \
# 0        51139.539444  51149.667700  51139.502000  124.334409  59952.900001
# 1        51139.539007  51149.667000  51139.529998  124.585284  59953.000001
# 2        51139.539135  51149.675500  51139.406998  124.713134  59953.100001
# 3        51139.539263  51149.684000  51139.283998  124.841128  59953.200001
# 4        51139.539390  51149.692500  51139.160998  125.022493  59953.300001
# ...               ...           ...           ...         ...           ...
# 8586393  51176.604327  51185.561801  51179.007055  159.344969  80054.900021
# 8586394  51176.607742  51185.568000  51179.269956  159.639142  80055.000021
# 8586395  51176.609655  51185.568800  51179.057956  160.085368  80055.100021
# 8586396  51176.611567  51185.569600  51178.845956  160.493581  80055.200021
# 8586397  51176.613480  51185.570400  51178.633956  160.787733  80055.300021
#
#          ...        TF3LVL        TF3UNC      TIME           VMX          VMY  \
# 0        ...  51632.193099  51619.558594  16:39:13 -48700.554688 -6450.494141
# 1        ...  51632.044671  51619.398438  16:39:13 -48718.007812 -6579.923340
# 2        ...  51631.896160  51619.234375  16:39:13 -48678.941406 -6743.762695
# 3        ...  51631.759367  51619.070312  16:39:13 -48604.972656 -6832.933594
# 4        ...  51631.634293  51618.921875  16:39:13 -48500.460938 -6835.408203
# ...      ...           ...           ...       ...           ...          ...
# 8586393  ...  50935.292190  50965.328125  22:14:15 -49983.785156  9229.302734
# 8586394  ...  50935.118334  50965.125000  22:14:15 -49980.175781  9195.800781
# 8586395  ...  50934.944499  50964.941406  22:14:15 -49967.292969  9209.247070
# 8586396  ...  50934.766758  50964.765625  22:14:15 -49944.406250  9261.607422
# 8586397  ...  50934.581204  50964.601562  22:14:15 -49916.359375  9344.724609
#
#                   VMZ    X_UTM_TRIM      X_UTM_WIN    Y_UTM_TRIM     Y_UTM_WIN
# 0       -14949.329102  2.478934e+05  247893.361519  4.240047e+06  4.240047e+06
# 1       -14832.922852  2.479004e+05  247900.394794  4.240047e+06  4.240047e+06
# 2       -14882.290039  2.479074e+05  247907.431427  4.240046e+06  4.240046e+06
# 3       -15077.395508  2.479145e+05  247914.464672  4.240046e+06  4.240046e+06
# 4       -15408.330078  2.479215e+05  247921.496387  4.240046e+06  4.240046e+06
# ...               ...           ...            ...           ...           ...
# 8586393   -900.194214 -1.000000e+32  335408.916821 -1.000000e+32  4.153225e+06
# 8586394  -1319.437012 -1.000000e+32  335408.814297 -1.000000e+32  4.153218e+06
# 8586395  -1677.718750 -1.000000e+32  335408.721881 -1.000000e+32  4.153210e+06
# 8586396  -1992.861694 -1.000000e+32  335408.640432 -1.000000e+32  4.153203e+06
# 8586397  -2245.814697 -1.000000e+32  335408.569880 -1.000000e+32  4.153196e+06
#
# [8586398 rows x 43 columns]

# %%
#Check to see if there are any nulls.  If no nulls are present in the data set, the answer is False
#If the answer is 'True', run the script below to replace all null values in the data set with a user selected value.
csvDataFrame.isnull().values.any()
# Out:
# False

# %% [markdown]
# No nulls shown as being present so we can check off that box on the review - alternative null value assigned.

# %%
# List Entity and Attribute information from metadata file
MDarrFields = []
MDarrDescription = []
MDarrUnit = []
MDarrCsvMax = []
MDarrCsvMin = []

for detailed in root.iter('detailed'):
 for enttyp in detailed.iter('enttyp'):
  enttypl = enttyp.find('enttypl')
  printmd ('**' + enttypl.text + "**")
  enttypd = enttyp.find('enttypd')
  printmd ('- ' + enttypd.text)
 for attr in detailed.findall('attr'):
  attrlabl = attr.find('attrlabl')
  print('\nattrlabl: ', attrlabl.text)
  MDarrFields.append(attrlabl.text)
  attrdef = attr.find('attrdef')
  print('attrdef: ', attrdef.text)
  MDarrDescription.append(attrdef.text)
  for attrdomv in attr.findall('attrdomv'):
    udom = attrdomv.find('udom')
    edom = attrdomv.find('edom')
    rdom = attrdomv.find('rdom')
    if udom != None:
     #print ('\t<Udom>')
     print('\t<udom>\t\t|-->', udom.text)
    if edom != None:
     for edom in attrdomv.findall('edom'):
      print ('\t<edom>')
      edomv = edom.find('edomv')
      print('\t\t<edomv>\t\t|-->', edomv.text)
      edomvd = edom.find('edomvd')
      print('\t\t\t<edomvd>\t|-->', edomvd.text)
      edomvds = edom.find('edomvds')      
      print('\t\t\t<edomvds>\t|-->', edomvds.text)   
    if rdom != None:  
     for rdom in attrdomv.findall('rdom'):
        print ('\t<rdom>')
        rdommin = rdom.find('rdommin')
        print('\t\t<rdomMIN>\t|-->', rdommin.text)
        rdommax = rdom.find('rdommax')
        print('\t\t<rdomMAX>\t|-->', rdommax.text)
# Out:
# **TotalMagneticIntensity.jpg**
# - Image of total magnetic intensity
# attrlabl:  Value
# attrdef:  Unique numeric values contained in each raster cell.
# 	<rdom>
# 		<rdomMIN>	|--> 0
# 		<rdomMAX>	|--> 255
# **Gap_TF3ANM.tif**
# - Raster geospatial data file.
# attrlabl:  nanoTesla
# attrdef:  Unique numeric values contained in each raster cell.
# 	<rdom>
# 		<rdomMIN>	|--> -675.17901611328
# 		<rdomMAX>	|--> 2774.9182128906
# **MO20F0196_USGS_GAP_MagneticFlightLineData.csv**
# - Dataset containing minimally processed (raw) magnetic data.
# attrlabl:  ALT
# attrdef:  WGS84 Altitude (metres AMSL)
# 	<rdom>
# 		<rdomMIN>	|--> 152.2
# 		<rdomMAX>	|--> 393.1
#
# attrlabl:  AZIMUTH
# attrdef:  Flight Line direction (ranged
# 	<rdom>
# 		<rdomMIN>	|--> -7.034545811279713e-05
# 		<rdomMAX>	|--> 360.00006438998673
#
# attrlabl:  DATE
# attrdef:  Flight Date (DD/MM/YYYY format - ASCII)
# 	<rdom>
# 		<rdomMIN>	|--> 2021.2027397260274
# 		<rdomMAX>	|--> 9999.0
#
# attrlabl:  DIUCON
# attrdef:  Consolidated Diurnal - using tied-in Backup Diurnal where required
# 	<rdom>
# 		<rdomMIN>	|--> 51121.95400035512
# 		<rdomMAX>	|--> 51187.86999974233
#
# attrlabl:  DIUEDIT
# attrdef:  Base Station Diurnal data (nT) -edited/de-spiked
# 	<rdom>
# 		<rdomMIN>	|--> 51121.95400035512
# 		<rdomMAX>	|--> 51589.95637066768
#
# attrlabl:  DIUEDIT2
# attrdef:  Backup Base Station Diurnal data (nT) -edited/de-spiked (if used)
# 	<rdom>
# 		<rdomMIN>	|--> 51016.36482638655
# 		<rdomMAX>	|--> 51201.7437218853
#
# attrlabl:  DIURNAL
# attrdef:  Base Station Diurnal data (nT) -measured
# 	<rdom>
# 		<rdomMIN>	|--> 50470.17693928254
# 		<rdomMAX>	|--> 51589.95637066768
#
# attrlabl:  DIURNAL2
# attrdef:  Backup Base Station Diurnal data (nT) -measured
# 	<rdom>
# 		<rdomMIN>	|--> 0.104939121256272
# 		<rdomMAX>	|--> 56176.57501070219
#
# attrlabl:  DTMFNL
# attrdef:  Final, corrected Digital Terrain Model  (m AMSL)
# 	<rdom>
# 		<rdomMIN>	|--> 16.994124314134982
# 		<rdomMAX>	|--> 291.7611925657331
#
# attrlabl:  FID
# attrdef:  Fiducial (UTC day-seconds)
# 	<rdom>
# 		<rdomMIN>	|--> 38367.80001458526
# 		<rdomMAX>	|--> 91681.40002070367
#
# attrlabl:  FLIGHT
# attrdef:  Flight Number
# 	<rdom>
# 		<rdomMIN>	|--> 13.0
# 		<rdomMAX>	|--> 96.0
#
# attrlabl:  HGEWFNL
# attrdef:  Final, measured East-West Magnetic gradient (nT/m)
# 	<rdom>
# 		<rdomMIN>	|--> -32.695221227227094
# 		<rdomMAX>	|--> 29.543117709894766
#
# attrlabl:  HGNSFNL
# attrdef:  Final, measured North-South Magnetic gradient (nT/m)
# 	<rdom>
# 		<rdomMIN>	|--> -14.266383609548317
# 		<rdomMAX>	|--> 18.791292674510498
#
# attrlabl:  IGRF_DEC
# attrdef:  IGRF Declination (Calculation date [2020 Coefficients]
# 	<rdom>
# 		<rdomMIN>	|--> -2.6538000191718356
# 		<rdomMAX>	|--> -1.7458
#
# attrlabl:  IGRF_INC
# attrdef:  IGRF Inclination (Calculation date [2020 Coefficients]
# 	<rdom>
# 		<rdomMIN>	|--> 64.91329998054505
# 		<rdomMAX>	|--> 66.08320003214628
#
# attrlabl:  IGRF_TF
# attrdef:  IGRF Total Field (Calculation date [2020 Coefficients]
# 	<rdom>
# 		<rdomMIN>	|--> 50774.05899336586
# 		<rdomMAX>	|--> 51573.83920643823
#
# attrlabl:  JULIAN
# attrdef:  Year+Julian Day
# 	<rdom>
# 		<rdomMIN>	|--> 202175.0
# 		<rdomMAX>	|--> 2021194.0
#
# attrlabl:  LAT
# attrdef:  Latitude (decimal degrees)
# 	<rdom>
# 		<rdomMIN>	|--> 36.83041508577423
# 		<rdomMAX>	|--> 38.29528422465964
#
# attrlabl:  LINE
# attrdef:  Line Number (ASCII; Prefix L
# 	<rdom>
# 		<rdomMIN>	|--> 1e+32
# 		<rdomMAX>	|--> -1e+32
#
# attrlabl:  LON
# attrdef:  Longitude (decimal degrees)
# 	<rdom>
# 		<rdomMIN>	|--> -89.95097715657224
# 		<rdomMAX>	|--> -88.83967198411617
#
# attrlabl:  RADAR
# attrdef:  Radar Altimeter (metres AGL)
# 	<rdom>
# 		<rdomMIN>	|--> 59.601561401367185
# 		<rdomMAX>	|--> 227.20222607421874
#
# attrlabl:  RADFNL
# attrdef:  Radar Altimeter corrected for system lag (metres AGL)
# 	<rdom>
# 		<rdomMIN>	|--> 59.15603038641735
# 		<rdomMAX>	|--> 226.30629546657067
#
# attrlabl:  TF1CMP
# attrdef:  Raw, Compensated TMI (Left WingTip, nT)
# 	<rdom>
# 		<rdomMIN>	|--> 42078.1597
# 		<rdomMAX>	|--> 54049.92578125
#
# attrlabl:  TF1CMPEDIT
# attrdef:  Edited (de-Spiked), Compensated TMI (Left WingTip, nT)
# 	<rdom>
# 		<rdomMIN>	|--> 50163.4140625
# 		<rdomMAX>	|--> 54049.92578125
#
# attrlabl:  TF1UNC
# attrdef:  Raw, Uncompensated TMI (Left WingTip, nT)
# 	<rdom>
# 		<rdomMIN>	|--> 42053.23046875
# 		<rdomMAX>	|--> 54038.296875
#
# attrlabl:  TF2CMP
# attrdef:  Raw, Compensated TMI (Right WingTip, nT)
# 	<rdom>
# 		<rdomMIN>	|--> 50179.30078125
# 		<rdomMAX>	|--> 53715.78515625
#
# attrlabl:  TF2CMPEDIT
# attrdef:  Edited (de-Spiked), Compensated TMI (Right WingTip, nT)
# 	<rdom>
# 		<rdomMIN>	|--> 50179.30078125
# 		<rdomMAX>	|--> 53715.78515625
#
# attrlabl:  TF2UNC
# attrdef:  Raw, Uncompensated TMI (Right WingTip, nT)
# 	<rdom>
# 		<rdomMIN>	|--> 50166.77734375
# 		<rdomMAX>	|--> 53710.0390625
#
# attrlabl:  TF3ANM
# attrdef:  Anomalous TMI (IGRF corrected, nT)
# 	<rdom>
# 		<rdomMIN>	|--> -683.8045732156461
# 		<rdomMAX>	|--> 2840.466988677508
#
# attrlabl:  TF3CMP
# attrdef:  Raw, Compensated TMI (Tail, nT) - Principal Magnetometer
# 	<rdom>
# 		<rdomMIN>	|--> 50195.15625
# 		<rdomMAX>	|--> 53841.99609375
#
# attrlabl:  TF3CMPEDIT
# attrdef:  Edited (de-Spiked), Compensated TMI (Tail, nT) - Principal Magnetometer
# 	<rdom>
# 		<rdomMIN>	|--> 50195.15625
# 		<rdomMAX>	|--> 53841.99609375
#
# attrlabl:  TF3DIU
# attrdef:  Diurnal corrected Tail TMI (nT)
# 	<rdom>
# 		<rdomMIN>	|--> 50208.47791175082
# 		<rdomMAX>	|--> 53863.16590563662
#
# attrlabl:  TF3FNL
# attrdef:  Final (micro-levelled) TMI (nT)
# 	<rdom>
# 		<rdomMIN>	|--> 50203.813361602384
# 		<rdomMAX>	|--> 53862.01928863233
#
# attrlabl:  TF3LVL
# attrdef:  Tie-line intersection levelled TMI (nT)
# 	<rdom>
# 		<rdomMIN>	|--> 50208.03743026934
# 		<rdomMAX>	|--> 53863.311313044025
#
# attrlabl:  TF3UNC
# attrdef:  Raw, Uncompensated TMI (Tail, nT) - Principal Magnetometer
# 	<rdom>
# 		<rdomMIN>	|--> 50188.890625
# 		<rdomMAX>	|--> 53834.140625
#
# attrlabl:  TIME
# attrdef:  UTC TIME (hh
# 	<rdom>
# 		<rdomMIN>	|--> 10.657722226273682
# 		<rdomMAX>	|--> 25.467055561306577
#
# attrlabl:  VMX
# attrdef:  Fluxgate X component (nT)
# 	<rdom>
# 		<rdomMIN>	|--> -51599.0625
# 		<rdomMAX>	|--> -15652.5712890625
#
# attrlabl:  VMY
# attrdef:  Fluxgate Y component (nT)
# 	<rdom>
# 		<rdomMIN>	|--> -34583.1328125
# 		<rdomMAX>	|--> 17154.3359375
#
# attrlabl:  VMZ
# attrdef:  Fluxgate Z component (nT)
# 	<rdom>
# 		<rdomMIN>	|--> -48452.1484375
# 		<rdomMAX>	|--> 49264.515625
#
# attrlabl:  X_UTM_TRIM
# attrdef:  UTM Easting - WGS84, UTM Zone 16N (metres) - trimmed for line overlap
# 	<rdom>
# 		<rdomMIN>	|--> 236824.4340386539
# 		<rdomMAX>	|--> 335993.89589584223
#
# attrlabl:  X_UTM_WIN
# attrdef:  UTM Easting - WGS84, UTM Zone 16N (metres)
# 	<rdom>
# 		<rdomMIN>	|--> 236824.4340386539
# 		<rdomMAX>	|--> 335993.89589584223
#
# attrlabl:  Y_UTM_TRIM
# attrdef:  UTM Northing - WGS84, UTM Zone 16N (metres) - trimmed for line overlap
# 	<rdom>
# 		<rdomMIN>	|--> 4080094.457927594
# 		<rdomMAX>	|--> 4240292.028284814
#
# attrlabl:  Y_UTM_WIN
# attrdef:  UTM Northing - WGS84, UTM Zone 16N (metres)
# 	<rdom>
# 		<rdomMIN>	|--> 4080094.457927594
# 		<rdomMAX>	|--> 4240292.028284814

# %%
# now get an array of the header names and print them out.
csvHeaderList = list(csvDataFrame.columns.values)
sortedCsvHeaderList = sorted(csvHeaderList)
ddFieldNames = jsonData['dataset_info']['channel_list']
sortedDdFieldNames = sorted(ddFieldNames)
sortedMDFieldNames = sorted(MDarrFields)
print ('-------------------------------------\nSORTED CSV HEADER LIST\n-------------------------------------') 
for i in range(len(sortedCsvHeaderList)):
 print (str(i) + ',' + sortedCsvHeaderList[i])
print ('\n------------------------------------\nSORTED DATA DICTIONARY HEADER LIST\n------------------------------------') 
for i in range(len(sortedDdFieldNames)):
 print (str(i) + ',' + sortedDdFieldNames[i])
print ('\n------------------------------------\nSORTED Metadata Attribute LIST\n------------------------------------') 
for i in range(len(sortedMDFieldNames)):
 print (str(i) + ',' + sortedMDFieldNames[i])
print ('\n-------------------------------------\nLIST COMPARISION\n------------------------------------')   
for i in range(len(sortedCsvHeaderList)):
 print (str(i) + ',' + sortedCsvHeaderList[i] + '::' + sortedDdFieldNames[i] + '::' + sortedMDFieldNames[i])
# Out:
# -------------------------------------
# SORTED CSV HEADER LIST
# -------------------------------------
# 0,ALT
# 1,AZIMUTH
# 2,DATE
# 3,DIUCON
# 4,DIUEDIT
# 5,DIUEDIT2
# 6,DIURNAL
# 7,DIURNAL2
# 8,DTMFNL
# 9,FID
# 10,FLIGHT
# 11,HGEWFNL
# 12,HGNSFNL
# 13,IGRF_DEC
# 14,IGRF_INC
# 15,IGRF_TF
# 16,JULIAN
# 17,LAT
# 18,LINE
# 19,LON
# 20,RADAR
# 21,RADFNL
# 22,TF1CMP
# 23,TF1CMPEDIT
# 24,TF1UNC
# 25,TF2CMP
# 26,TF2CMPEDIT
# 27,TF2UNC
# 28,TF3ANM
# 29,TF3CMP
# 30,TF3CMPEDIT
# 31,TF3DIU
# 32,TF3FNL
# 33,TF3LVL
# 34,TF3UNC
# 35,TIME
# 36,VMX
# 37,VMY
# 38,VMZ
# 39,X_UTM_TRIM
# 40,X_UTM_WIN
# 41,Y_UTM_TRIM
# 42,Y_UTM_WIN
#
# ------------------------------------
# SORTED DATA DICTIONARY HEADER LIST
# ------------------------------------
# 0,ALT
# 1,AZIMUTH
# 2,DATE
# 3,DIUCON
# 4,DIUEDIT
# 5,DIUEDIT2
# 6,DIURNAL
# 7,DIURNAL2
# 8,DTMFNL
# 9,FID
# 10,FLIGHT
# 11,HGEWFNL
# 12,HGNSFNL
# 13,IGRF_DEC
# 14,IGRF_INC
# 15,IGRF_TF
# 16,JULIAN
# 17,LAT
# 18,LINE
# 19,LON
# 20,RADAR
# 21,RADFNL
# 22,TF1CMP
# 23,TF1CMPEDIT
# 24,TF1UNC
# 25,TF2CMP
# 26,TF2CMPEDIT
# 27,TF2UNC
# 28,TF3ANM
# 29,TF3CMP
# 30,TF3CMPEDIT
# 31,TF3DIU
# 32,TF3FNL
# 33,TF3LVL
# 34,TF3UNC
# 35,TIME
# 36,VMX
# 37,VMY
# 38,VMZ
# 39,X_UTM_TRIM
# 40,X_UTM_WIN
# 41,Y_UTM_TRIM
# 42,Y_UTM_WIN
#
# ------------------------------------
# SORTED Metadata Attribute LIST
# ------------------------------------
# 0,ALT
# 1,AZIMUTH
# 2,DATE
# 3,DIUCON
# 4,DIUEDIT
# 5,DIUEDIT2
# 6,DIURNAL
# 7,DIURNAL2
# 8,DTMFNL
# 9,FID
# 10,FLIGHT
# 11,HGEWFNL
# 12,HGNSFNL
# 13,IGRF_DEC
# 14,IGRF_INC
# 15,IGRF_TF
# 16,JULIAN
# 17,LAT
# 18,LINE
# 19,LON
# 20,RADAR
# 21,RADFNL
# 22,TF1CMP
# 23,TF1CMPEDIT
# 24,TF1UNC
# 25,TF2CMP
# 26,TF2CMPEDIT
# 27,TF2UNC
# 28,TF3ANM
# 29,TF3CMP
# 30,TF3CMPEDIT
# 31,TF3DIU
# 32,TF3FNL
# 33,TF3LVL
# 34,TF3UNC
# 35,TIME
# 36,VMX
# 37,VMY
# 38,VMZ
# 39,Value
# 40,X_UTM_TRIM
# 41,X_UTM_WIN
# 42,Y_UTM_TRIM
# 43,Y_UTM_WIN
# 44,nanoTesla
#
# -------------------------------------
# LIST COMPARISION
# ------------------------------------
# 0,ALT::ALT::ALT
# 1,AZIMUTH::AZIMUTH::AZIMUTH
# 2,DATE::DATE::DATE
# 3,DIUCON::DIUCON::DIUCON
# 4,DIUEDIT::DIUEDIT::DIUEDIT
# 5,DIUEDIT2::DIUEDIT2::DIUEDIT2
# 6,DIURNAL::DIURNAL::DIURNAL
# 7,DIURNAL2::DIURNAL2::DIURNAL2
# 8,DTMFNL::DTMFNL::DTMFNL
# 9,FID::FID::FID
# 10,FLIGHT::FLIGHT::FLIGHT
# 11,HGEWFNL::HGEWFNL::HGEWFNL
# 12,HGNSFNL::HGNSFNL::HGNSFNL
# 13,IGRF_DEC::IGRF_DEC::IGRF_DEC
# 14,IGRF_INC::IGRF_INC::IGRF_INC
# 15,IGRF_TF::IGRF_TF::IGRF_TF
# 16,JULIAN::JULIAN::JULIAN
# 17,LAT::LAT::LAT
# 18,LINE::LINE::LINE
# 19,LON::LON::LON
# 20,RADAR::RADAR::RADAR
# 21,RADFNL::RADFNL::RADFNL
# 22,TF1CMP::TF1CMP::TF1CMP
# 23,TF1CMPEDIT::TF1CMPEDIT::TF1CMPEDIT
# 24,TF1UNC::TF1UNC::TF1UNC
# 25,TF2CMP::TF2CMP::TF2CMP
# 26,TF2CMPEDIT::TF2CMPEDIT::TF2CMPEDIT
# 27,TF2UNC::TF2UNC::TF2UNC
# 28,TF3ANM::TF3ANM::TF3ANM
# 29,TF3CMP::TF3CMP::TF3CMP
# 30,TF3CMPEDIT::TF3CMPEDIT::TF3CMPEDIT
# 31,TF3DIU::TF3DIU::TF3DIU
# 32,TF3FNL::TF3FNL::TF3FNL
# 33,TF3LVL::TF3LVL::TF3LVL
# 34,TF3UNC::TF3UNC::TF3UNC
# 35,TIME::TIME::TIME
# 36,VMX::VMX::VMX
# 37,VMY::VMY::VMY
# 38,VMZ::VMZ::VMZ
# 39,X_UTM_TRIM::X_UTM_TRIM::Value
# 40,X_UTM_WIN::X_UTM_WIN::X_UTM_TRIM
# 41,Y_UTM_TRIM::Y_UTM_TRIM::X_UTM_WIN
# 42,Y_UTM_WIN::Y_UTM_WIN::Y_UTM_TRIM

# %% [markdown]
# > - Disregard the extra "value" channel picked up in the metadata listing - that's a bug in my code.
# > - **All channels line up - no desired changes.**

# %%
#Creat Min and Max Arrays
#Calculate Min Max and print result:
csvMax = []
csvMin = []

#Loop through arrays and callculate values
for i in range(len(csvHeaderList)):
 print (csvHeaderList[i] + ': ' + str(i))
 strCol = csvHeaderList[i]
 csvMax.append(csvDataFrame[strCol].max())
 csvMin.append(csvDataFrame[strCol].min())
 print ('Min. Value ' + csvHeaderList[i] + ' :' + str(csvMin[i]))
 print ('Max. Value ' + csvHeaderList[i] + ' :' + str(csvMax[i]))
# Out:
# ALT: 0
# Min. Value ALT :152.2
# Max. Value ALT :393.1
# AZIMUTH: 1
# Min. Value AZIMUTH :-7.03454581127e-05
# Max. Value AZIMUTH :360.000064389987
# DATE: 2
# Min. Value DATE :2021/03/16
# Max. Value DATE :9999/01/01
# DIUCON: 3
# Min. Value DIUCON :51121.9540003551
# Max. Value DIUCON :51187.8699997423
# DIUEDIT: 4
# Min. Value DIUEDIT :51121.9540003551
# Max. Value DIUEDIT :51589.9563706677
# DIUEDIT2: 5
# Min. Value DIUEDIT2 :-1e+32
# Max. Value DIUEDIT2 :51201.7437218853
# DIURNAL: 6
# Min. Value DIURNAL :50470.1769392825
# Max. Value DIURNAL :51589.9563706677
# DIURNAL2: 7
# Min. Value DIURNAL2 :-1e+32
# Max. Value DIURNAL2 :56176.5750107022
# DTMFNL: 8
# Min. Value DTMFNL :-1e+32
# Max. Value DTMFNL :291.761192565733
# FID: 9
# Min. Value FID :38367.8000145853
# Max. Value FID :91681.4000207037
# FLIGHT: 10
# Min. Value FLIGHT :13
# Max. Value FLIGHT :96
# HGEWFNL: 11
# Min. Value HGEWFNL :-1e+32
# Max. Value HGEWFNL :29.5431177098948
# HGNSFNL: 12
# Min. Value HGNSFNL :-1e+32
# Max. Value HGNSFNL :18.7912926745105
# IGRF_DEC: 13
# Min. Value IGRF_DEC :-1e+32
# Max. Value IGRF_DEC :-1.7458
# IGRF_INC: 14
# Min. Value IGRF_INC :-1e+32
# Max. Value IGRF_INC :66.0832000321463
# IGRF_TF: 15
# Min. Value IGRF_TF :-1e+32
# Max. Value IGRF_TF :51573.8392064382
# JULIAN: 16
# Min. Value JULIAN :202175
# Max. Value JULIAN :2021194
# LAT: 17
# Min. Value LAT :36.8304150857742
# Max. Value LAT :38.2952842246596
# LINE: 18
# Min. Value LINE :L100
# Max. Value LINE :T10291
# LON: 19
# Min. Value LON :-89.9509771565722
# Max. Value LON :-88.8396719841162
# RADAR: 20
# Min. Value RADAR :-1e+32
# Max. Value RADAR :227.202226074219
# RADFNL: 21
# Min. Value RADFNL :-1e+32
# Max. Value RADFNL :226.306295466571
# TF1CMP: 22
# Min. Value TF1CMP :42078.1597
# Max. Value TF1CMP :54049.92578125
# TF1CMPEDIT: 23
# Min. Value TF1CMPEDIT :-1e+32
# Max. Value TF1CMPEDIT :54049.92578125
# TF1UNC: 24
# Min. Value TF1UNC :42053.23046875
# Max. Value TF1UNC :54038.296875
# TF2CMP: 25
# Min. Value TF2CMP :50179.30078125
# Max. Value TF2CMP :53715.78515625
# TF2CMPEDIT: 26
# Min. Value TF2CMPEDIT :50179.30078125
# Max. Value TF2CMPEDIT :53715.78515625
# TF2UNC: 27
# Min. Value TF2UNC :50166.77734375
# Max. Value TF2UNC :53710.0390625
# TF3ANM: 28
# Min. Value TF3ANM :-1e+32
# Max. Value TF3ANM :2840.46698867751
# TF3CMP: 29
# Min. Value TF3CMP :50195.15625
# Max. Value TF3CMP :53841.99609375
# TF3CMPEDIT: 30
# Min. Value TF3CMPEDIT :50195.15625
# Max. Value TF3CMPEDIT :53841.99609375
# TF3DIU: 31
# Min. Value TF3DIU :-1e+32
# Max. Value TF3DIU :53863.1659056366
# TF3FNL: 32
# Min. Value TF3FNL :-1e+32
# Max. Value TF3FNL :53862.0192886323
# TF3LVL: 33
# Min. Value TF3LVL :-1e+32
# Max. Value TF3LVL :53863.311313044
# TF3UNC: 34
# Min. Value TF3UNC :50188.890625
# Max. Value TF3UNC :53834.140625
# TIME: 35
# Min. Value TIME :10:39:28
# Max. Value TIME :25:28:01
# VMX: 36
# Min. Value VMX :-51599.0625
# Max. Value VMX :-15652.5712890625
# VMY: 37
# Min. Value VMY :-34583.1328125
# Max. Value VMY :17154.3359375
# VMZ: 38
# Min. Value VMZ :-48452.1484375
# Max. Value VMZ :49264.515625
# X_UTM_TRIM: 39
# Min. Value X_UTM_TRIM :-1e+32
# Max. Value X_UTM_TRIM :335993.895895842
# X_UTM_WIN: 40
# Min. Value X_UTM_WIN :-1e+32
# Max. Value X_UTM_WIN :335993.895895842
# Y_UTM_TRIM: 41
# Min. Value Y_UTM_TRIM :-1e+32
# Max. Value Y_UTM_TRIM :4240292.02828481
# Y_UTM_WIN: 42
# Min. Value Y_UTM_WIN :-1e+32
# Max. Value Y_UTM_WIN :4240292.02828481

# %% [markdown]
# ###### d.	If applicable, geographic coordinates are provided, and they match location keywords in metadata and also agree with the data;

# %%
# Get the bounding coordinates from the metadata
# Compare this to the metadata Entity and Atribute item
for bounding in root.iter('bounding'):
 westbc = bounding.find('westbc')
 print ('westbc: ' + westbc.text)
 eastbc = bounding.find('eastbc')
 print ('eastbc: ' + eastbc.text)
 northbc = bounding.find('northbc')
 print ('northbc: ' + northbc.text)
 southbc = bounding.find('southbc')
 print ('southbc: ' + southbc.text)
# Out:
# westbc: -89.9509
# eastbc: -88.8396
# northbc: 38.2952
# southbc: 36.8304

# %% [markdown]
# > - No desired changes to bounding coordinates.

# %% [markdown]
# ##### e.	Keywords accurately represent the data and include terms from standard vocabularies whenever possible (such as the USGS Thesaurus, http://www.usgs.gov/science/services.html or  the Biocomplexity Thesaurus, http://www.usgs.gov/core_science_systems/csas/biocomplexity_thesaurus

# %%
#Load Theme Keywords
printmd ('***Theme Keywords*** <br> ===============')
for theme in root.iter('theme'):
 themekt = theme.find('themekt')
 printmd ("**" + themekt.text + "**")
 for themekey in theme.findall('themekey'):
        printmd('- ' + themekey.text)
# Out:
# ***Theme Keywords*** <br> ===============
# **USGS Thesaurus**
# - economy
# - geophysics
# - geospatial datasets
# - geoscientific information
# - aeromagnetic surveying
# - magnetic field (earth)
# - horizontal magnetic gradiometry
# - aeroradiometric surveying
# - potassium
# - uranium
# - thorium
# - radon
# **none**
# - AASG
# - Association of State Geologists
# - Geology, Geophysics, and Geochemistry Science Center
# - GGGSC
# - Earth Mapping Resources Initiative
# - EarthMRI
# - horizontal magnetic gradiometry
# - airborne geophysical survey
# - Mineral Resources Program
# - MRP
# - Earthquake Hazards Program
# - EHP
# - National Cooperative Geologic Mapping Program
# - NCGMP
# - U.S. Geological Survey
# - USGS
# **ISO 19115 Topic Category**
# - geoscientificInformation
# - economy

# %% [markdown]
# <b>Unrecognized keyword: "economy"</b>
#
# <b>Unrecognized keyword: "geoscientific information"</b>
#
# <b>Unrecognized keyword: "horizontal magnetic gradiometry"</b>
# > - please add these to thesaurus "none"

# %%
#Load Place Keywords
printmd ('***Place Keywords*** <br> ==============')
for place in root.iter('place'):
 placekt = place.find('placekt')
 printmd ("**" + placekt.text + "**")
 for placekey in place.findall('placekey'):
        printmd('- ' + placekey.text)
# Out:
# ***Place Keywords*** <br> ==============
# **Geographic Names Information System (GNIS)**
# - Ballard County
# - Carlisle County
# - Jackson County
# - Jefferson County
# - Johnson County
# - Massac County
# - Alexander County
# - McCracken County
# - Perry County
# - Pulaski County
# - Randolph County
# - St. Clair County
# - Union County
# - Washington County
# - Williamson County
# - Franklin County
# - Bollinger County
# - Cape Girardeau County
# - Mississippi County
# - New Madrid County
# - Perry County
# - Scott County
# - Stoddard County
# - Cape Girardeau
# **Common geographic areas**
# - United States
# - Missouri
# - Illinois
# - Kentucky
# **Types**
# - Downloadable
# - GeoTIFF
# - Map Service
# - Rasters

# %% [markdown]
# > - No desired changes to keywords

# %% [markdown]
# ##### f. Information about data processing steps, methodology, and lineage are included in the record and match any associated publications. Could a scientist or technician recreate the final data set from the descriptions? Can documentation about methodology be easily found and used? Are processing software and versions identified, if applicable?;

# %%
#Load process steps
for procstep in root.iter('procstep'):
 procdesc = procstep.find('procdesc')
 print (procdesc.text)
 procdate = procstep.find('procdate')
 print ('- ' + procdate.text + '\n')
# Out:
# The airborne survey was flown under contract to the U.S. Geological Survey by Terraquest, Ltd from March 16, 2021 to July 13, 2021. The magnetic data were acquired with 3 cesium vapor magnetometers. The radiometric data were acquired with radiation Solutions RS-500 gamma ray spectrometer. Data were collected along north-south flight lines spaced 250 meters (m) apart with east-west tie lines flown every 3500 m. A mean terrain clearance of 100 m was maintained; in some areas safety dictated a higher elevation. A total of 64,227.3 line-kilometers (km) of data were collected.
# - 20210713
#
# 1) Lag Correction of Total Magnetic Field, 2) Diurnal Data and diurnal correction of Total Magnetic Field, 3) Total Magnetic Field Tie-Traverse Line Intersection Leveling, 4) Total Magnetic Field Micro-leveling, 5) Calculated Vertical Derivative, 6) Measured Horizontal Gradients, 7) Reconstructed Total Magnetic Field (RTF), 8) Data Gridding, 9) Magnetic Database Output
# - 20211115
#
# Final data and contractor's report were accepted and received by USGS from Terraquest Ltd
# - 20211115
#
# Final data were exported to CSV-format and NetCDF to meet open data requirements.
# - 20220404
#
# Shapefile of the locations of the airborne geophysical survey flightlines
# - 20220404

# %% [markdown]
# > - No desired changes to process steps

# %% [markdown]
# ##### g. The metadata provides complete and current information about how to use the data files – access instructions, unusual software requirements, data models, definitions of terms, size of the data, etc;

# %% [markdown]
# >- no desired changes

# %% [markdown]
# ###### h.	The data quality section adequately describes the procedures used to ensure the quality of the data;

# %%
#Load data quality items
for attracc in root.iter('attracc'):
 attraccr = attracc.find('attraccr')
 printmd ('- attraccr <br> ' + attraccr.text)
for dataqual in root.iter('dataqual'):
 logic = dataqual.find('logic')
 printmd ('- logic <br> ' + logic.text)
for dataqual in root.iter('dataqual'):
 complete = dataqual.find('complete')
 printmd ('- complete <br> ' + complete.text)
for horizpa in root.iter('horizpa'):
 horizpar = horizpa.find('horizpar')
 printmd ('- horizpar <br> ' + horizpar.text)
for vertacc in root.iter('vertacc'):
 vertaccr = vertacc.find('vertaccr')
 printmd ('- vertaccr <br> ' + vertaccr.text)
# Out:
# - attraccr <br> Daily quality control of raw radiometric and magnetic data was performed by the contractor and is described in the contractor report. Further quality control measures occurred post flight by the contractor and USGS scientist-in-charge before approval and acceptance of the final data. The data have been peer reviewed and compared with related ancillary data.
# - logic <br> Data were visually inspected for reasonableness and spatial consistency.
# - complete <br> Data set is considered complete for the information presented, as described in the abstract. Users are advised to read the rest of the metadata record carefully for additional details. All data as part of this collection were included in this data release for the region and time period specified in this metadata.
# - horizpar <br> Field quality control and assurance procedures were undertaken by the Terraquest field crew and are described in the contractor's report included with this data release.
# - vertaccr <br> Field quality control and assurance procedures were undertaken by the Terraquest field crew and are described in the contractor's report included with this data release.

# %% [markdown]
# > **No desired changes.**

# %% [markdown]
# ###### i.	Access constraints, use constraints, and distribution liability statements are included and are consistent with USGS policy:
# - desired accconst:<br>
# None. Please see 'Distribution Info' for details.
#
#
# - desired useconst:<br>
# Any use of trade, firm, or product names is for descriptive purposes only and does not imply endorsement by the U.S. Government.  Although these data have been processed successfully on a computer system at the U.S. Geological Survey (USGS), no warranty expressed or implied is made regarding the display or utility of the data for other purposes, nor on all computer systems, nor shall the act of distribution constitute any such warranty. The USGS or the U.S. Government shall not be held liable for improper or incorrect use of the data described and/or contained herein.
#
#
# - desired distliab:<br>
# Unless otherwise stated, all data, metadata and related materials are considered to satisfy the quality standards relative to the purpose for which the data were collected. Although these data and associated metadata have been reviewed for accuracy and completeness and approved for release by the U.S. Geological Survey (USGS), no warranty expressed or implied is made regarding the display or utility of the data for other purposes, nor on all computer systems, nor shall the act of distribution constitute any such warranty.

# %%
# Load liability statements to check against above text
for idinfo in root.iter('idinfo'):
 accconst = idinfo.find('accconst')
 printmd ('- actual accconst: <br> ' + accconst.text)
for idinfo in root.iter('idinfo'):
 useconst = idinfo.find('useconst')
 printmd ('- actual useconst: <br> ' + useconst.text)
for distinfo in root.iter('distinfo'):
 distliab = distinfo.find('distliab')
 printmd ('- actual distliab: <br> ' + distliab.text)
# Out:
# - actual accconst: <br> None. Please see 'Distribution Info' for details
# - actual useconst: <br> Any use of trade, firm, or product names is for descriptive purposes only and does not imply endorsement by the U.S. Government. Although these data have been processed successfully on a computer system at the U.S. Geological Survey (USGS), no warranty expressed or implied is made regarding the display or utility of the data for other purposes, nor on all computer systems, nor shall the act of distribution constitute any such warranty. The USGS or the U.S. Government shall not be held liable for improper or incorrect use of the data described and/or contained herein.
# - actual distliab: <br> Unless otherwise stated, all data, metadata and related materials are considered to satisfy the quality standards relative to the purpose for which the data were collected. Although these data and associated metadata have been reviewed for accuracy and completeness and approved for release by the U.S. Geological Survey (USGS), no warranty expressed or implied is made regarding the display or utility of the data for other purposes, nor on all computer systems, nor shall the act of distribution constitute any such warranty.

# %% [markdown]
# > - **No Desired Changes**

# %% [markdown]
# ##### j.	If the data or metadata have been revised, correct version identification is provided (see: https://www2.usgs.gov/fsp/data_versioning.asp);

# %% [markdown]
# > - **Not Applicable**

# %% [markdown]
# ##### k.	Content is written in a way that is usable and helpful, without use of special formatting or characters that will fail to be transferred to XML (generally metadata should be encoded using UTF-8).**

# %% [markdown]
# > - **Yes**
